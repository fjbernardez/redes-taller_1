# %%
# !pip install scapy
from scapy.all import *
import math
# Out:
# Requirement already satisfied: scapy in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (2.5.0)

# %%
S1 = {}
def probabilidad(apariciones,total):
  return apariciones/total
def informacion(apariciones,total):
  return math.log2(1/probabilidad(apariciones,total))
def mostrar_fuente(S):
    N = sum(S.values())
    simbolos = sorted(S.items(), key=lambda x: -x[1])
    print("\n".join([ " %s : Probabilidad %.5f : Información %.5f " % (d,probabilidad(k,N),informacion(k,N)) for d,k in simbolos ]))
    entropia = 0
    for d,k in simbolos:
      entropia += probabilidad(k,N)* math.log2(1/probabilidad(k,N))
    print("Entropia de la fuente %.5f con %i paquetes leidos \n " % (entropia,N))
def callback(pkt):
    if pkt.haslayer(Ether):
        dire = "BROADCAST" if pkt[Ether].dst=="ff:ff:ff:ff:ff:ff" else "UNICAST"
        proto = pkt[Ether].type # El campo type del frame tiene el protocolo
        s_i = (dire, proto) # Aca se define el simbolo de la fuente
        if s_i not in S1:
            S1[s_i] = 0.0
        S1[s_i] += 1.0
    mostrar_fuente(S1)

# %%
scapy_cap = rdpcap('completedCapture.pcap')
for packet in scapy_cap:
    callback(packet)
# Out:
#  ('BROADCAST', 2048) : Probabilidad 1.00000 : Información 0.00000
# Entropia de la fuente 0.00000 con 1 paquetes leidos
#
#  ('BROADCAST', 2048) : Probabilidad 0.50000 : Información 1.00000
#  ('UNICAST', 2048) : Probabilidad 0.50000 : Información 1.00000
# Entropia de la fuente 1.00000 con 2 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.66667 : Información 0.58496
#  ('BROADCAST', 2048) : Probabilidad 0.33333 : Información 1.58496
# Entropia de la fuente 0.91830 con 3 paquetes leidos
#
#  ('BROADCAST', 2048) : Probabilidad 0.50000 : Información 1.00000
#  ('UNICAST', 2048) : Probabilidad 0.50000 : Información 1.00000
# Entropia de la fuente 1.00000 con 4 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.60000 : Información 0.73697
#  ('BROADCAST', 2048) : Probabilidad 0.40000 : Información 1.32193
# Entropia de la fuente 0.97095 con 5 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.66667 : Información 0.58496
#  ('BROADCAST', 2048) : Probabilidad 0.33333 : Información 1.58496
# Entropia de la fuente 0.91830 con 6 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.71429 : Información 0.48543
#  ('BROADCAST', 2048) : Probabilidad 0.28571 : Información 1.80735
# Entropia de la fuente 0.86312 con 7 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.75000 : Información 0.41504
#  ('BROADCAST', 2048) : Probabilidad 0.25000 : Información 2.00000
# Entropia de la fuente 0.81128 con 8 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.77778 : Información 0.36257
#  ('BROADCAST', 2048) : Probabilidad 0.22222 : Información 2.16993
# Entropia de la fuente 0.76420 con 9 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.70000 : Información 0.51457
#  ('BROADCAST', 2048) : Probabilidad 0.30000 : Información 1.73697
# Entropia de la fuente 0.88129 con 10 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.63636 : Información 0.65208
#  ('BROADCAST', 2048) : Probabilidad 0.27273 : Información 1.87447
#  ('UNICAST', 2054) : Probabilidad 0.09091 : Información 3.45943
# Entropia de la fuente 1.24067 con 11 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.58333 : Información 0.77761
#  ('BROADCAST', 2048) : Probabilidad 0.25000 : Información 2.00000
#  ('UNICAST', 2054) : Probabilidad 0.16667 : Información 2.58496
# Entropia de la fuente 1.38443 con 12 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.53846 : Información 0.89308
#  ('BROADCAST', 2048) : Probabilidad 0.30769 : Información 1.70044
#  ('UNICAST', 2054) : Probabilidad 0.15385 : Información 2.70044
# Entropia de la fuente 1.41956 con 13 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.50000 : Información 1.00000
#  ('BROADCAST', 2048) : Probabilidad 0.35714 : Información 1.48543
#  ('UNICAST', 2054) : Probabilidad 0.14286 : Información 2.80735
# Entropia de la fuente 1.43156 con 14 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.46667 : Información 1.09954
#  ('BROADCAST', 2048) : Probabilidad 0.40000 : Información 1.32193
#  ('UNICAST', 2054) : Probabilidad 0.13333 : Información 2.90689
# Entropia de la fuente 1.42947 con 15 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.50000 : Información 1.00000
#  ('BROADCAST', 2048) : Probabilidad 0.37500 : Información 1.41504
#  ('UNICAST', 2054) : Probabilidad 0.12500 : Información 3.00000
# Entropia de la fuente 1.40564 con 16 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.47059 : Información 1.08746
#  ('BROADCAST', 2048) : Probabilidad 0.41176 : Información 1.28011
#  ('UNICAST', 2054) : Probabilidad 0.11765 : Información 3.08746
# Entropia de la fuente 1.40208 con 17 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.50000 : Información 1.00000
#  ('BROADCAST', 2048) : Probabilidad 0.38889 : Información 1.36257
#  ('UNICAST', 2054) : Probabilidad 0.11111 : Información 3.16993
# Entropia de la fuente 1.38210 con 18 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.52632 : Información 0.92600
#  ('BROADCAST', 2048) : Probabilidad 0.36842 : Información 1.44057
#  ('UNICAST', 2054) : Probabilidad 0.10526 : Información 3.24793
# Entropia de la fuente 1.35999 con 19 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.55000 : Información 0.86250
#  ('BROADCAST', 2048) : Probabilidad 0.35000 : Información 1.51457
#  ('UNICAST', 2054) : Probabilidad 0.10000 : Información 3.32193
# Entropia de la fuente 1.33667 con 20 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.52381 : Información 0.93289
#  ('BROADCAST', 2048) : Probabilidad 0.38095 : Información 1.39232
#  ('UNICAST', 2054) : Probabilidad 0.09524 : Información 3.39232
# Entropia de la fuente 1.34214 con 21 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.50000 : Información 1.00000
#  ('BROADCAST', 2048) : Probabilidad 0.36364 : Información 1.45943
#  ('UNICAST', 2054) : Probabilidad 0.13636 : Información 2.87447
# Entropia de la fuente 1.42268 con 22 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.47826 : Información 1.06413
#  ('BROADCAST', 2048) : Probabilidad 0.34783 : Información 1.52356
#  ('UNICAST', 2054) : Probabilidad 0.17391 : Información 2.52356
# Entropia de la fuente 1.47775 con 23 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.45833 : Información 1.12553
#  ('BROADCAST', 2048) : Probabilidad 0.37500 : Información 1.41504
#  ('UNICAST', 2054) : Probabilidad 0.16667 : Información 2.58496
# Entropia de la fuente 1.47733 con 24 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.48000 : Información 1.05889
#  ('BROADCAST', 2048) : Probabilidad 0.36000 : Información 1.47393
#  ('UNICAST', 2054) : Probabilidad 0.16000 : Información 2.64386
# Entropia de la fuente 1.46190 con 25 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.50000 : Información 1.00000
#  ('BROADCAST', 2048) : Probabilidad 0.34615 : Información 1.53051
#  ('UNICAST', 2054) : Probabilidad 0.15385 : Información 2.70044
# Entropia de la fuente 1.44525 con 26 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.51852 : Información 0.94753
#  ('BROADCAST', 2048) : Probabilidad 0.33333 : Información 1.58496
#  ('UNICAST', 2054) : Probabilidad 0.14815 : Información 2.75489
# Entropia de la fuente 1.42777 con 27 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.50000 : Información 1.00000
#  ('BROADCAST', 2048) : Probabilidad 0.32143 : Información 1.63743
#  ('UNICAST', 2054) : Probabilidad 0.17857 : Información 2.48543
# Entropia de la fuente 1.47014 con 28 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.48276 : Información 1.05063
#  ('BROADCAST', 2048) : Probabilidad 0.31034 : Información 1.68806
#  ('UNICAST', 2054) : Probabilidad 0.20690 : Información 2.27302
# Entropia de la fuente 1.50136 con 29 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.46667 : Información 1.09954
#  ('BROADCAST', 2048) : Probabilidad 0.33333 : Información 1.58496
#  ('UNICAST', 2054) : Probabilidad 0.20000 : Información 2.32193
# Entropia de la fuente 1.50582 con 30 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.45161 : Información 1.14684
#  ('BROADCAST', 2048) : Probabilidad 0.32258 : Información 1.63227
#  ('UNICAST', 2054) : Probabilidad 0.22581 : Información 2.14684
# Entropia de la fuente 1.52924 con 31 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.43750 : Información 1.19265
#  ('BROADCAST', 2048) : Probabilidad 0.31250 : Información 1.67807
#  ('UNICAST', 2054) : Probabilidad 0.25000 : Información 2.00000
# Entropia de la fuente 1.54618 con 32 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.45455 : Información 1.13750
#  ('BROADCAST', 2048) : Probabilidad 0.30303 : Información 1.72247
#  ('UNICAST', 2054) : Probabilidad 0.24242 : Información 2.04439
# Entropia de la fuente 1.53462 con 33 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.47059 : Información 1.08746
#  ('BROADCAST', 2048) : Probabilidad 0.29412 : Información 1.76553
#  ('UNICAST', 2054) : Probabilidad 0.23529 : Información 2.08746
# Entropia de la fuente 1.52219 con 34 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.48571 : Información 1.04182
#  ('BROADCAST', 2048) : Probabilidad 0.28571 : Información 1.80735
#  ('UNICAST', 2054) : Probabilidad 0.22857 : Información 2.12928
# Entropia de la fuente 1.50911 con 35 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.50000 : Información 1.00000
#  ('BROADCAST', 2048) : Probabilidad 0.27778 : Información 1.84800
#  ('UNICAST', 2054) : Probabilidad 0.22222 : Información 2.16993
# Entropia de la fuente 1.49554 con 36 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.48649 : Información 1.03953
#  ('BROADCAST', 2048) : Probabilidad 0.29730 : Información 1.75002
#  ('UNICAST', 2054) : Probabilidad 0.21622 : Información 2.20945
# Entropia de la fuente 1.50371 con 37 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.50000 : Información 1.00000
#  ('BROADCAST', 2048) : Probabilidad 0.28947 : Información 1.78850
#  ('UNICAST', 2054) : Probabilidad 0.21053 : Información 2.24793
# Entropia de la fuente 1.49097 con 38 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.51282 : Información 0.96347
#  ('BROADCAST', 2048) : Probabilidad 0.28205 : Información 1.82597
#  ('UNICAST', 2054) : Probabilidad 0.20513 : Información 2.28540
# Entropia de la fuente 1.47791 con 39 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.52500 : Información 0.92961
#  ('BROADCAST', 2048) : Probabilidad 0.27500 : Información 1.86250
#  ('UNICAST', 2054) : Probabilidad 0.20000 : Información 2.32193
# Entropia de la fuente 1.46462 con 40 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.53659 : Información 0.89812
#  ('BROADCAST', 2048) : Probabilidad 0.26829 : Información 1.89812
#  ('UNICAST', 2054) : Probabilidad 0.19512 : Información 2.35755
# Entropia de la fuente 1.45118 con 41 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.54762 : Información 0.86876
#  ('BROADCAST', 2048) : Probabilidad 0.26190 : Información 1.93289
#  ('UNICAST', 2054) : Probabilidad 0.19048 : Información 2.39232
# Entropia de la fuente 1.43766 con 42 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.55814 : Información 0.84130
#  ('BROADCAST', 2048) : Probabilidad 0.25581 : Información 1.96683
#  ('UNICAST', 2054) : Probabilidad 0.18605 : Información 2.42626
# Entropia de la fuente 1.42411 con 43 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.56818 : Información 0.81558
#  ('BROADCAST', 2048) : Probabilidad 0.25000 : Información 2.00000
#  ('UNICAST', 2054) : Probabilidad 0.18182 : Información 2.45943
# Entropia de la fuente 1.41056 con 44 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.57778 : Información 0.79141
#  ('BROADCAST', 2048) : Probabilidad 0.24444 : Información 2.03242
#  ('UNICAST', 2054) : Probabilidad 0.17778 : Información 2.49185
# Entropia de la fuente 1.39707 con 45 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.58696 : Información 0.76867
#  ('BROADCAST', 2048) : Probabilidad 0.23913 : Información 2.06413
#  ('UNICAST', 2054) : Probabilidad 0.17391 : Información 2.52356
# Entropia de la fuente 1.38366 con 46 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.57447 : Información 0.79970
#  ('BROADCAST', 2048) : Probabilidad 0.25532 : Información 1.96963
#  ('UNICAST', 2054) : Probabilidad 0.17021 : Información 2.55459
# Entropia de la fuente 1.39711 con 47 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.58333 : Información 0.77761
#  ('BROADCAST', 2048) : Probabilidad 0.25000 : Información 2.00000
#  ('UNICAST', 2054) : Probabilidad 0.16667 : Información 2.58496
# Entropia de la fuente 1.38443 con 48 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.59184 : Información 0.75673
#  ('BROADCAST', 2048) : Probabilidad 0.24490 : Información 2.02975
#  ('UNICAST', 2054) : Probabilidad 0.16327 : Información 2.61471
# Entropia de la fuente 1.37183 con 49 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.60000 : Información 0.73697
#  ('BROADCAST', 2048) : Probabilidad 0.24000 : Información 2.05889
#  ('UNICAST', 2054) : Probabilidad 0.16000 : Información 2.64386
# Entropia de la fuente 1.35933 con 50 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.60784 : Información 0.71823
#  ('BROADCAST', 2048) : Probabilidad 0.23529 : Información 2.08746
#  ('UNICAST', 2054) : Probabilidad 0.15686 : Información 2.67243
# Entropia de la fuente 1.34694 con 51 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.61538 : Información 0.70044
#  ('BROADCAST', 2048) : Probabilidad 0.23077 : Información 2.11548
#  ('UNICAST', 2054) : Probabilidad 0.15385 : Información 2.70044
# Entropia de la fuente 1.33468 con 52 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.62264 : Información 0.68353
#  ('BROADCAST', 2048) : Probabilidad 0.22642 : Información 2.14296
#  ('UNICAST', 2054) : Probabilidad 0.15094 : Información 2.72792
# Entropia de la fuente 1.32255 con 53 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.62963 : Información 0.66742
#  ('BROADCAST', 2048) : Probabilidad 0.22222 : Información 2.16993
#  ('UNICAST', 2054) : Probabilidad 0.14815 : Información 2.75489
# Entropia de la fuente 1.31057 con 54 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.63636 : Información 0.65208
#  ('BROADCAST', 2048) : Probabilidad 0.21818 : Información 2.19640
#  ('UNICAST', 2054) : Probabilidad 0.14545 : Información 2.78136
# Entropia de la fuente 1.29873 con 55 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.64286 : Información 0.63743
#  ('BROADCAST', 2048) : Probabilidad 0.21429 : Información 2.22239
#  ('UNICAST', 2054) : Probabilidad 0.14286 : Información 2.80735
# Entropia de la fuente 1.28705 con 56 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.64912 : Información 0.62344
#  ('BROADCAST', 2048) : Probabilidad 0.21053 : Información 2.24793
#  ('UNICAST', 2054) : Probabilidad 0.14035 : Información 2.83289
# Entropia de la fuente 1.27553 con 57 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.65517 : Información 0.61005
#  ('BROADCAST', 2048) : Probabilidad 0.20690 : Información 2.27302
#  ('UNICAST', 2054) : Probabilidad 0.13793 : Información 2.85798
# Entropia de la fuente 1.26417 con 58 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.66102 : Información 0.59724
#  ('BROADCAST', 2048) : Probabilidad 0.20339 : Información 2.29768
#  ('UNICAST', 2054) : Probabilidad 0.13559 : Información 2.88264
# Entropia de la fuente 1.25298 con 59 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.66667 : Información 0.58496
#  ('BROADCAST', 2048) : Probabilidad 0.20000 : Información 2.32193
#  ('UNICAST', 2054) : Probabilidad 0.13333 : Información 2.90689
# Entropia de la fuente 1.24195 con 60 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.65574 : Información 0.60881
#  ('BROADCAST', 2048) : Probabilidad 0.21311 : Información 2.23030
#  ('UNICAST', 2054) : Probabilidad 0.13115 : Información 2.93074
# Entropia de la fuente 1.25889 con 61 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.64516 : Información 0.63227
#  ('BROADCAST', 2048) : Probabilidad 0.22581 : Información 2.14684
#  ('UNICAST', 2054) : Probabilidad 0.12903 : Información 2.95420
# Entropia de la fuente 1.27387 con 62 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.63492 : Información 0.65535
#  ('BROADCAST', 2048) : Probabilidad 0.23810 : Información 2.07039
#  ('UNICAST', 2054) : Probabilidad 0.12698 : Información 2.97728
# Entropia de la fuente 1.28711 con 63 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.64062 : Información 0.64245
#  ('BROADCAST', 2048) : Probabilidad 0.23438 : Información 2.09311
#  ('UNICAST', 2054) : Probabilidad 0.12500 : Información 3.00000
# Entropia de la fuente 1.27714 con 64 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.63077 : Información 0.66482
#  ('BROADCAST', 2048) : Probabilidad 0.24615 : Información 2.02237
#  ('UNICAST', 2054) : Probabilidad 0.12308 : Información 3.02237
# Entropia de la fuente 1.28914 con 65 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.62121 : Información 0.68684
#  ('BROADCAST', 2048) : Probabilidad 0.24242 : Información 2.04439
#  ('UNICAST', 2054) : Probabilidad 0.13636 : Información 2.87447
# Entropia de la fuente 1.31426 con 66 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.61194 : Información 0.70854
#  ('BROADCAST', 2048) : Probabilidad 0.23881 : Información 2.06609
#  ('UNICAST', 2054) : Probabilidad 0.14925 : Información 2.74416
# Entropia de la fuente 1.33655 con 67 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.60294 : Información 0.72991
#  ('BROADCAST', 2048) : Probabilidad 0.25000 : Información 2.00000
#  ('UNICAST', 2054) : Probabilidad 0.14706 : Información 2.76553
# Entropia de la fuente 1.34679 con 68 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.60870 : Información 0.71621
#  ('BROADCAST', 2048) : Probabilidad 0.24638 : Información 2.02106
#  ('UNICAST', 2054) : Probabilidad 0.14493 : Información 2.78660
# Entropia de la fuente 1.33775 con 69 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.61429 : Información 0.70302
#  ('BROADCAST', 2048) : Probabilidad 0.24286 : Información 2.04182
#  ('UNICAST', 2054) : Probabilidad 0.14286 : Información 2.80735
# Entropia de la fuente 1.32878 con 70 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.61972 : Información 0.69032
#  ('BROADCAST', 2048) : Probabilidad 0.23944 : Información 2.06228
#  ('UNICAST', 2054) : Probabilidad 0.14085 : Información 2.82782
# Entropia de la fuente 1.31987 con 71 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.61111 : Información 0.71049
#  ('BROADCAST', 2048) : Probabilidad 0.25000 : Información 2.00000
#  ('UNICAST', 2054) : Probabilidad 0.13889 : Información 2.84800
# Entropia de la fuente 1.32975 con 72 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.60274 : Información 0.73039
#  ('BROADCAST', 2048) : Probabilidad 0.26027 : Información 1.94190
#  ('UNICAST', 2054) : Probabilidad 0.13699 : Información 2.86790
# Entropia de la fuente 1.33852 con 73 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.60811 : Información 0.71760
#  ('BROADCAST', 2048) : Probabilidad 0.25676 : Información 1.96153
#  ('UNICAST', 2054) : Probabilidad 0.13514 : Información 2.88753
# Entropia de la fuente 1.33022 con 74 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.61333 : Información 0.70526
#  ('BROADCAST', 2048) : Probabilidad 0.25333 : Información 1.98089
#  ('UNICAST', 2054) : Probabilidad 0.13333 : Información 2.90689
# Entropia de la fuente 1.32197 con 75 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.61842 : Información 0.69334
#  ('BROADCAST', 2048) : Probabilidad 0.25000 : Información 2.00000
#  ('UNICAST', 2054) : Probabilidad 0.13158 : Información 2.92600
# Entropia de la fuente 1.31378 con 76 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.62338 : Información 0.68182
#  ('BROADCAST', 2048) : Probabilidad 0.24675 : Información 2.01886
#  ('UNICAST', 2054) : Probabilidad 0.12987 : Información 2.94486
# Entropia de la fuente 1.30564 con 77 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.62821 : Información 0.67069
#  ('BROADCAST', 2048) : Probabilidad 0.24359 : Información 2.03747
#  ('UNICAST', 2054) : Probabilidad 0.12821 : Información 2.96347
# Entropia de la fuente 1.29757 con 78 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.63291 : Información 0.65992
#  ('BROADCAST', 2048) : Probabilidad 0.24051 : Información 2.05585
#  ('UNICAST', 2054) : Probabilidad 0.12658 : Información 2.98185
# Entropia de la fuente 1.28957 con 79 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.63750 : Información 0.64950
#  ('BROADCAST', 2048) : Probabilidad 0.23750 : Información 2.07400
#  ('UNICAST', 2054) : Probabilidad 0.12500 : Información 3.00000
# Entropia de la fuente 1.28163 con 80 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.64198 : Información 0.63941
#  ('BROADCAST', 2048) : Probabilidad 0.23457 : Información 2.09192
#  ('UNICAST', 2054) : Probabilidad 0.12346 : Información 3.01792
# Entropia de la fuente 1.27377 con 81 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.64634 : Información 0.62963
#  ('BROADCAST', 2048) : Probabilidad 0.23171 : Información 2.10962
#  ('UNICAST', 2054) : Probabilidad 0.12195 : Información 3.03562
# Entropia de la fuente 1.26597 con 82 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.65060 : Información 0.62015
#  ('BROADCAST', 2048) : Probabilidad 0.22892 : Información 2.12711
#  ('UNICAST', 2054) : Probabilidad 0.12048 : Información 3.05311
# Entropia de la fuente 1.25825 con 83 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.65476 : Información 0.61096
#  ('BROADCAST', 2048) : Probabilidad 0.22619 : Información 2.14439
#  ('UNICAST', 2054) : Probabilidad 0.11905 : Información 3.07039
# Entropia de la fuente 1.25059 con 84 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.65882 : Información 0.60204
#  ('BROADCAST', 2048) : Probabilidad 0.22353 : Información 2.16146
#  ('UNICAST', 2054) : Probabilidad 0.11765 : Información 3.08746
# Entropia de la fuente 1.24302 con 85 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.66279 : Información 0.59337
#  ('BROADCAST', 2048) : Probabilidad 0.22093 : Información 2.17834
#  ('UNICAST', 2054) : Probabilidad 0.11628 : Información 3.10434
# Entropia de la fuente 1.23551 con 86 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.66667 : Información 0.58496
#  ('BROADCAST', 2048) : Probabilidad 0.21839 : Información 2.19502
#  ('UNICAST', 2054) : Probabilidad 0.11494 : Información 3.12102
# Entropia de la fuente 1.22808 con 87 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.65909 : Información 0.60145
#  ('BROADCAST', 2048) : Probabilidad 0.22727 : Información 2.13750
#  ('UNICAST', 2054) : Probabilidad 0.11364 : Información 3.13750
# Entropia de la fuente 1.23874 con 88 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.66292 : Información 0.59309
#  ('BROADCAST', 2048) : Probabilidad 0.22472 : Información 2.15381
#  ('UNICAST', 2054) : Probabilidad 0.11236 : Información 3.15381
# Entropia de la fuente 1.23153 con 89 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.66667 : Información 0.58496
#  ('BROADCAST', 2048) : Probabilidad 0.22222 : Información 2.16993
#  ('UNICAST', 2054) : Probabilidad 0.11111 : Información 3.16993
# Entropia de la fuente 1.22439 con 90 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.67033 : Información 0.57706
#  ('BROADCAST', 2048) : Probabilidad 0.21978 : Información 2.18587
#  ('UNICAST', 2054) : Probabilidad 0.10989 : Información 3.18587
# Entropia de la fuente 1.21732 con 91 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.66304 : Información 0.59282
#  ('BROADCAST', 2048) : Probabilidad 0.22826 : Información 2.13124
#  ('UNICAST', 2054) : Probabilidad 0.10870 : Información 3.20163
# Entropia de la fuente 1.22755 con 92 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.66667 : Información 0.58496
#  ('BROADCAST', 2048) : Probabilidad 0.22581 : Información 2.14684
#  ('UNICAST', 2054) : Probabilidad 0.10753 : Información 3.21723
# Entropia de la fuente 1.22068 con 93 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.67021 : Información 0.57731
#  ('BROADCAST', 2048) : Probabilidad 0.22340 : Información 2.16227
#  ('UNICAST', 2054) : Probabilidad 0.10638 : Información 3.23266
# Entropia de la fuente 1.21388 con 94 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.67368 : Información 0.56986
#  ('BROADCAST', 2048) : Probabilidad 0.22105 : Información 2.17754
#  ('UNICAST', 2054) : Probabilidad 0.10526 : Información 3.24793
# Entropia de la fuente 1.20714 con 95 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.67708 : Información 0.56259
#  ('BROADCAST', 2048) : Probabilidad 0.21875 : Información 2.19265
#  ('UNICAST', 2054) : Probabilidad 0.10417 : Información 3.26303
# Entropia de la fuente 1.20046 con 96 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.68041 : Información 0.55552
#  ('BROADCAST', 2048) : Probabilidad 0.21649 : Información 2.20760
#  ('UNICAST', 2054) : Probabilidad 0.10309 : Información 3.27798
# Entropia de la fuente 1.19385 con 97 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.68367 : Información 0.54862
#  ('BROADCAST', 2048) : Probabilidad 0.21429 : Información 2.22239
#  ('UNICAST', 2054) : Probabilidad 0.10204 : Información 3.29278
# Entropia de la fuente 1.18730 con 98 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.68687 : Información 0.54189
#  ('BROADCAST', 2048) : Probabilidad 0.21212 : Información 2.23704
#  ('UNICAST', 2054) : Probabilidad 0.10101 : Información 3.30743
# Entropia de la fuente 1.18082 con 99 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.69000 : Información 0.53533
#  ('BROADCAST', 2048) : Probabilidad 0.21000 : Información 2.25154
#  ('UNICAST', 2054) : Probabilidad 0.10000 : Información 3.32193
# Entropia de la fuente 1.17439 con 100 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.69307 : Información 0.52893
#  ('BROADCAST', 2048) : Probabilidad 0.20792 : Información 2.26589
#  ('UNICAST', 2054) : Probabilidad 0.09901 : Información 3.33628
# Entropia de la fuente 1.16804 con 101 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.69608 : Información 0.52268
#  ('BROADCAST', 2048) : Probabilidad 0.20588 : Información 2.28011
#  ('UNICAST', 2054) : Probabilidad 0.09804 : Información 3.35050
# Entropia de la fuente 1.16174 con 102 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.69903 : Información 0.51658
#  ('BROADCAST', 2048) : Probabilidad 0.20388 : Información 2.29418
#  ('UNICAST', 2054) : Probabilidad 0.09709 : Información 3.36457
# Entropia de la fuente 1.15550 con 103 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.70192 : Información 0.51062
#  ('BROADCAST', 2048) : Probabilidad 0.20192 : Información 2.30812
#  ('UNICAST', 2054) : Probabilidad 0.09615 : Información 3.37851
# Entropia de la fuente 1.14933 con 104 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.70476 : Información 0.50479
#  ('BROADCAST', 2048) : Probabilidad 0.20000 : Información 2.32193
#  ('UNICAST', 2054) : Probabilidad 0.09524 : Información 3.39232
# Entropia de la fuente 1.14322 con 105 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.70755 : Información 0.49910
#  ('BROADCAST', 2048) : Probabilidad 0.19811 : Información 2.33560
#  ('UNICAST', 2054) : Probabilidad 0.09434 : Información 3.40599
# Entropia de la fuente 1.13717 con 106 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.71028 : Información 0.49354
#  ('BROADCAST', 2048) : Probabilidad 0.19626 : Información 2.34915
#  ('UNICAST', 2054) : Probabilidad 0.09346 : Información 3.41954
# Entropia de la fuente 1.13118 con 107 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.71296 : Información 0.48810
#  ('BROADCAST', 2048) : Probabilidad 0.19444 : Información 2.36257
#  ('UNICAST', 2054) : Probabilidad 0.09259 : Información 3.43296
# Entropia de la fuente 1.12525 con 108 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.71560 : Información 0.48278
#  ('BROADCAST', 2048) : Probabilidad 0.19266 : Información 2.37587
#  ('UNICAST', 2054) : Probabilidad 0.09174 : Información 3.44626
# Entropia de la fuente 1.11938 con 109 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.71818 : Información 0.47758
#  ('BROADCAST', 2048) : Probabilidad 0.19091 : Información 2.38904
#  ('UNICAST', 2054) : Probabilidad 0.09091 : Información 3.45943
# Entropia de la fuente 1.11357 con 110 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.72072 : Información 0.47249
#  ('BROADCAST', 2048) : Probabilidad 0.18919 : Información 2.40210
#  ('UNICAST', 2054) : Probabilidad 0.09009 : Información 3.47249
# Entropia de la fuente 1.10782 con 111 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.72321 : Información 0.46750
#  ('BROADCAST', 2048) : Probabilidad 0.18750 : Información 2.41504
#  ('UNICAST', 2054) : Probabilidad 0.08929 : Información 3.48543
# Entropia de la fuente 1.10212 con 112 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.72566 : Información 0.46263
#  ('BROADCAST', 2048) : Probabilidad 0.18584 : Información 2.42786
#  ('UNICAST', 2054) : Probabilidad 0.08850 : Información 3.49825
# Entropia de la fuente 1.09649 con 113 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.72807 : Información 0.45785
#  ('BROADCAST', 2048) : Probabilidad 0.18421 : Información 2.44057
#  ('UNICAST', 2054) : Probabilidad 0.08772 : Información 3.51096
# Entropia de la fuente 1.09091 con 114 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73043 : Información 0.45317
#  ('BROADCAST', 2048) : Probabilidad 0.18261 : Información 2.45317
#  ('UNICAST', 2054) : Probabilidad 0.08696 : Información 3.52356
# Entropia de la fuente 1.08538 con 115 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73276 : Información 0.44859
#  ('BROADCAST', 2048) : Probabilidad 0.18103 : Información 2.46566
#  ('UNICAST', 2054) : Probabilidad 0.08621 : Información 3.53605
# Entropia de la fuente 1.07991 con 116 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73504 : Información 0.44410
#  ('BROADCAST', 2048) : Probabilidad 0.17949 : Información 2.47805
#  ('UNICAST', 2054) : Probabilidad 0.08547 : Información 3.54844
# Entropia de la fuente 1.07450 con 117 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73729 : Información 0.43970
#  ('BROADCAST', 2048) : Probabilidad 0.17797 : Información 2.49033
#  ('UNICAST', 2054) : Probabilidad 0.08475 : Información 3.56071
# Entropia de la fuente 1.06913 con 118 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73950 : Información 0.43539
#  ('BROADCAST', 2048) : Probabilidad 0.17647 : Información 2.50250
#  ('UNICAST', 2054) : Probabilidad 0.08403 : Información 3.57289
# Entropia de la fuente 1.06383 con 119 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74167 : Información 0.43116
#  ('BROADCAST', 2048) : Probabilidad 0.17500 : Información 2.51457
#  ('UNICAST', 2054) : Probabilidad 0.08333 : Información 3.58496
# Entropia de la fuente 1.05857 con 120 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74380 : Información 0.42701
#  ('BROADCAST', 2048) : Probabilidad 0.17355 : Información 2.52655
#  ('UNICAST', 2054) : Probabilidad 0.08264 : Información 3.59694
# Entropia de la fuente 1.05337 con 121 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74590 : Información 0.42294
#  ('BROADCAST', 2048) : Probabilidad 0.17213 : Información 2.53842
#  ('UNICAST', 2054) : Probabilidad 0.08197 : Información 3.60881
# Entropia de la fuente 1.04822 con 122 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74797 : Información 0.41895
#  ('BROADCAST', 2048) : Probabilidad 0.17073 : Información 2.55020
#  ('UNICAST', 2054) : Probabilidad 0.08130 : Información 3.62059
# Entropia de la fuente 1.04312 con 123 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.75000 : Información 0.41504
#  ('BROADCAST', 2048) : Probabilidad 0.16935 : Información 2.56188
#  ('UNICAST', 2054) : Probabilidad 0.08065 : Información 3.63227
# Entropia de la fuente 1.03807 con 124 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.75200 : Información 0.41120
#  ('BROADCAST', 2048) : Probabilidad 0.16800 : Información 2.57347
#  ('UNICAST', 2054) : Probabilidad 0.08000 : Información 3.64386
# Entropia de la fuente 1.03307 con 125 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.75397 : Información 0.40742
#  ('BROADCAST', 2048) : Probabilidad 0.16667 : Información 2.58496
#  ('UNICAST', 2054) : Probabilidad 0.07937 : Información 3.65535
# Entropia de la fuente 1.02812 con 126 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.75591 : Información 0.40372
#  ('BROADCAST', 2048) : Probabilidad 0.16535 : Información 2.59637
#  ('UNICAST', 2054) : Probabilidad 0.07874 : Información 3.66676
# Entropia de la fuente 1.02322 con 127 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.75781 : Información 0.40009
#  ('BROADCAST', 2048) : Probabilidad 0.16406 : Información 2.60768
#  ('UNICAST', 2054) : Probabilidad 0.07812 : Información 3.67807
# Entropia de la fuente 1.01836 con 128 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.75969 : Información 0.39652
#  ('BROADCAST', 2048) : Probabilidad 0.16279 : Información 2.61891
#  ('UNICAST', 2054) : Probabilidad 0.07752 : Información 3.68930
# Entropia de la fuente 1.01356 con 129 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.76154 : Información 0.39301
#  ('BROADCAST', 2048) : Probabilidad 0.16154 : Información 2.63005
#  ('UNICAST', 2054) : Probabilidad 0.07692 : Información 3.70044
# Entropia de la fuente 1.00880 con 130 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.76336 : Información 0.38957
#  ('BROADCAST', 2048) : Probabilidad 0.16031 : Información 2.64111
#  ('UNICAST', 2054) : Probabilidad 0.07634 : Información 3.71149
# Entropia de la fuente 1.00408 con 131 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.76515 : Información 0.38618
#  ('BROADCAST', 2048) : Probabilidad 0.15909 : Información 2.65208
#  ('UNICAST', 2054) : Probabilidad 0.07576 : Información 3.72247
# Entropia de la fuente 0.99941 con 132 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.76692 : Información 0.38286
#  ('BROADCAST', 2048) : Probabilidad 0.15789 : Información 2.66297
#  ('UNICAST', 2054) : Probabilidad 0.07519 : Información 3.73335
# Entropia de la fuente 0.99479 con 133 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.76866 : Información 0.37959
#  ('BROADCAST', 2048) : Probabilidad 0.15672 : Información 2.67377
#  ('UNICAST', 2054) : Probabilidad 0.07463 : Información 3.74416
# Entropia de la fuente 0.99021 con 134 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.77037 : Información 0.37638
#  ('BROADCAST', 2048) : Probabilidad 0.15556 : Información 2.68450
#  ('UNICAST', 2054) : Probabilidad 0.07407 : Información 3.75489
# Entropia de la fuente 0.98568 con 135 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.77206 : Información 0.37322
#  ('BROADCAST', 2048) : Probabilidad 0.15441 : Información 2.69515
#  ('UNICAST', 2054) : Probabilidad 0.07353 : Información 3.76553
# Entropia de la fuente 0.98119 con 136 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.77372 : Información 0.37011
#  ('BROADCAST', 2048) : Probabilidad 0.15328 : Información 2.70571
#  ('UNICAST', 2054) : Probabilidad 0.07299 : Información 3.77610
# Entropia de la fuente 0.97674 con 137 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.77536 : Información 0.36706
#  ('BROADCAST', 2048) : Probabilidad 0.15217 : Información 2.71621
#  ('UNICAST', 2054) : Probabilidad 0.07246 : Información 3.78660
# Entropia de la fuente 0.97233 con 138 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.76978 : Información 0.37747
#  ('BROADCAST', 2048) : Probabilidad 0.15827 : Información 2.65951
#  ('UNICAST', 2054) : Probabilidad 0.07194 : Información 3.79701
# Entropia de la fuente 0.98467 con 139 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.77143 : Información 0.37440
#  ('BROADCAST', 2048) : Probabilidad 0.15714 : Información 2.66985
#  ('UNICAST', 2054) : Probabilidad 0.07143 : Información 3.80735
# Entropia de la fuente 0.98032 con 140 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.76596 : Información 0.38466
#  ('BROADCAST', 2048) : Probabilidad 0.15603 : Información 2.68012
#  ('UNICAST', 2054) : Probabilidad 0.07801 : Información 3.68012
# Entropia de la fuente 0.99991 con 141 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.76056 : Información 0.39486
#  ('BROADCAST', 2048) : Probabilidad 0.15493 : Información 2.69032
#  ('UNICAST', 2054) : Probabilidad 0.08451 : Información 3.56478
# Entropia de la fuente 1.01837 con 142 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.75524 : Información 0.40498
#  ('BROADCAST', 2048) : Probabilidad 0.15385 : Información 2.70044
#  ('UNICAST', 2054) : Probabilidad 0.09091 : Información 3.45943
# Entropia de la fuente 1.03581 con 143 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.75000 : Información 0.41504
#  ('BROADCAST', 2048) : Probabilidad 0.15278 : Información 2.71049
#  ('UNICAST', 2054) : Probabilidad 0.09722 : Información 3.36257
# Entropia de la fuente 1.05230 con 144 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74483 : Información 0.42502
#  ('BROADCAST', 2048) : Probabilidad 0.15862 : Información 2.65635
#  ('UNICAST', 2054) : Probabilidad 0.09655 : Información 3.37255
# Entropia de la fuente 1.06355 con 145 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74658 : Información 0.42164
#  ('BROADCAST', 2048) : Probabilidad 0.15753 : Información 2.66626
#  ('UNICAST', 2054) : Probabilidad 0.09589 : Información 3.38247
# Entropia de la fuente 1.05916 con 146 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74150 : Información 0.43149
#  ('BROADCAST', 2048) : Probabilidad 0.16327 : Información 2.61471
#  ('UNICAST', 2054) : Probabilidad 0.09524 : Información 3.39232
# Entropia de la fuente 1.06992 con 147 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73649 : Información 0.44127
#  ('BROADCAST', 2048) : Probabilidad 0.16892 : Información 2.56560
#  ('UNICAST', 2054) : Probabilidad 0.09459 : Información 3.40210
# Entropia de la fuente 1.08019 con 148 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73154 : Información 0.45098
#  ('BROADCAST', 2048) : Probabilidad 0.17450 : Información 2.51873
#  ('UNICAST', 2054) : Probabilidad 0.09396 : Información 3.41181
# Entropia de la fuente 1.09000 con 149 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73333 : Información 0.44746
#  ('BROADCAST', 2048) : Probabilidad 0.17333 : Información 2.52838
#  ('UNICAST', 2054) : Probabilidad 0.09333 : Información 3.42146
# Entropia de la fuente 1.08573 con 150 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73510 : Información 0.44399
#  ('BROADCAST', 2048) : Probabilidad 0.17219 : Información 2.53797
#  ('UNICAST', 2054) : Probabilidad 0.09272 : Información 3.43105
# Entropia de la fuente 1.08149 con 151 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73684 : Información 0.44057
#  ('BROADCAST', 2048) : Probabilidad 0.17105 : Información 2.54749
#  ('UNICAST', 2054) : Probabilidad 0.09211 : Información 3.44057
# Entropia de la fuente 1.07728 con 152 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73203 : Información 0.45003
#  ('BROADCAST', 2048) : Probabilidad 0.17647 : Información 2.50250
#  ('UNICAST', 2054) : Probabilidad 0.09150 : Información 3.45003
# Entropia de la fuente 1.08674 con 153 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73377 : Información 0.44661
#  ('BROADCAST', 2048) : Probabilidad 0.17532 : Información 2.51190
#  ('UNICAST', 2054) : Probabilidad 0.09091 : Información 3.45943
# Entropia de la fuente 1.08260 con 154 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73548 : Información 0.44323
#  ('BROADCAST', 2048) : Probabilidad 0.17419 : Información 2.52124
#  ('UNICAST', 2054) : Probabilidad 0.09032 : Información 3.46877
# Entropia de la fuente 1.07848 con 155 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73718 : Información 0.43991
#  ('BROADCAST', 2048) : Probabilidad 0.17308 : Información 2.53051
#  ('UNICAST', 2054) : Probabilidad 0.08974 : Información 3.47805
# Entropia de la fuente 1.07440 con 156 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73885 : Información 0.43664
#  ('BROADCAST', 2048) : Probabilidad 0.17197 : Información 2.53973
#  ('UNICAST', 2054) : Probabilidad 0.08917 : Información 3.48727
# Entropia de la fuente 1.07035 con 157 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74051 : Información 0.43342
#  ('BROADCAST', 2048) : Probabilidad 0.17089 : Información 2.54889
#  ('UNICAST', 2054) : Probabilidad 0.08861 : Información 3.49643
# Entropia de la fuente 1.06633 con 158 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73585 : Información 0.44252
#  ('BROADCAST', 2048) : Probabilidad 0.16981 : Información 2.55800
#  ('UNICAST', 2054) : Probabilidad 0.08805 : Información 3.50553
#  ('BROADCAST', 2054) : Probabilidad 0.00629 : Información 7.31288
# Entropia de la fuente 1.11466 con 159 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73125 : Información 0.45156
#  ('BROADCAST', 2048) : Probabilidad 0.17500 : Información 2.51457
#  ('UNICAST', 2054) : Probabilidad 0.08750 : Información 3.51457
#  ('BROADCAST', 2054) : Probabilidad 0.00625 : Información 7.32193
# Entropia de la fuente 1.12354 con 160 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73292 : Información 0.44827
#  ('BROADCAST', 2048) : Probabilidad 0.17391 : Información 2.52356
#  ('UNICAST', 2054) : Probabilidad 0.08696 : Información 3.52356
#  ('BROADCAST', 2054) : Probabilidad 0.00621 : Información 7.33092
# Entropia de la fuente 1.11936 con 161 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73457 : Información 0.44503
#  ('BROADCAST', 2048) : Probabilidad 0.17284 : Información 2.53250
#  ('UNICAST', 2054) : Probabilidad 0.08642 : Información 3.53250
#  ('BROADCAST', 2054) : Probabilidad 0.00617 : Información 7.33985
# Entropia de la fuente 1.11521 con 162 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73620 : Información 0.44184
#  ('BROADCAST', 2048) : Probabilidad 0.17178 : Información 2.54137
#  ('UNICAST', 2054) : Probabilidad 0.08589 : Información 3.54137
#  ('BROADCAST', 2054) : Probabilidad 0.00613 : Información 7.34873
# Entropia de la fuente 1.11109 con 163 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73780 : Información 0.43869
#  ('BROADCAST', 2048) : Probabilidad 0.17073 : Información 2.55020
#  ('UNICAST', 2054) : Probabilidad 0.08537 : Información 3.55020
#  ('BROADCAST', 2054) : Probabilidad 0.00610 : Información 7.35755
# Entropia de la fuente 1.10699 con 164 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73939 : Información 0.43558
#  ('BROADCAST', 2048) : Probabilidad 0.16970 : Información 2.55897
#  ('UNICAST', 2054) : Probabilidad 0.08485 : Información 3.55897
#  ('BROADCAST', 2054) : Probabilidad 0.00606 : Información 7.36632
# Entropia de la fuente 1.10294 con 165 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74096 : Información 0.43252
#  ('BROADCAST', 2048) : Probabilidad 0.16867 : Información 2.56768
#  ('UNICAST', 2054) : Probabilidad 0.08434 : Información 3.56768
#  ('BROADCAST', 2054) : Probabilidad 0.00602 : Información 7.37504
# Entropia de la fuente 1.09891 con 166 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74251 : Información 0.42951
#  ('BROADCAST', 2048) : Probabilidad 0.16766 : Información 2.57635
#  ('UNICAST', 2054) : Probabilidad 0.08383 : Información 3.57635
#  ('BROADCAST', 2054) : Probabilidad 0.00599 : Información 7.38370
# Entropia de la fuente 1.09491 con 167 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74405 : Información 0.42653
#  ('BROADCAST', 2048) : Probabilidad 0.16667 : Información 2.58496
#  ('UNICAST', 2054) : Probabilidad 0.08333 : Información 3.58496
#  ('BROADCAST', 2054) : Probabilidad 0.00595 : Información 7.39232
# Entropia de la fuente 1.09094 con 168 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74556 : Información 0.42360
#  ('BROADCAST', 2048) : Probabilidad 0.16568 : Información 2.59352
#  ('UNICAST', 2054) : Probabilidad 0.08284 : Información 3.59352
#  ('BROADCAST', 2054) : Probabilidad 0.00592 : Información 7.40088
# Entropia de la fuente 1.08700 con 169 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74118 : Información 0.43211
#  ('BROADCAST', 2048) : Probabilidad 0.16471 : Información 2.60204
#  ('UNICAST', 2054) : Probabilidad 0.08824 : Información 3.50250
#  ('BROADCAST', 2054) : Probabilidad 0.00588 : Información 7.40939
# Entropia de la fuente 1.10147 con 170 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73684 : Información 0.44057
#  ('BROADCAST', 2048) : Probabilidad 0.16374 : Información 2.61050
#  ('UNICAST', 2054) : Probabilidad 0.09357 : Información 3.41785
#  ('BROADCAST', 2054) : Probabilidad 0.00585 : Información 7.41785
# Entropia de la fuente 1.11526 con 171 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73256 : Información 0.44898
#  ('BROADCAST', 2048) : Probabilidad 0.16860 : Información 2.56828
#  ('UNICAST', 2054) : Probabilidad 0.09302 : Información 3.42626
#  ('BROADCAST', 2054) : Probabilidad 0.00581 : Información 7.42626
# Entropia de la fuente 1.12383 con 172 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73410 : Información 0.44594
#  ('BROADCAST', 2048) : Probabilidad 0.16763 : Información 2.57665
#  ('UNICAST', 2054) : Probabilidad 0.09249 : Información 3.43463
#  ('BROADCAST', 2054) : Probabilidad 0.00578 : Información 7.43463
# Entropia de la fuente 1.11992 con 173 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73563 : Información 0.44294
#  ('BROADCAST', 2048) : Probabilidad 0.16667 : Información 2.58496
#  ('UNICAST', 2054) : Probabilidad 0.09195 : Información 3.44294
#  ('BROADCAST', 2054) : Probabilidad 0.00575 : Información 7.44294
# Entropia de la fuente 1.11604 con 174 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73714 : Información 0.43998
#  ('BROADCAST', 2048) : Probabilidad 0.16571 : Información 2.59323
#  ('UNICAST', 2054) : Probabilidad 0.09143 : Información 3.45121
#  ('BROADCAST', 2054) : Probabilidad 0.00571 : Información 7.45121
# Entropia de la fuente 1.11218 con 175 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73864 : Información 0.43706
#  ('BROADCAST', 2048) : Probabilidad 0.16477 : Información 2.60145
#  ('UNICAST', 2054) : Probabilidad 0.09091 : Información 3.45943
#  ('BROADCAST', 2054) : Probabilidad 0.00568 : Información 7.45943
# Entropia de la fuente 1.10836 con 176 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.74011 : Información 0.43418
#  ('BROADCAST', 2048) : Probabilidad 0.16384 : Información 2.60962
#  ('UNICAST', 2054) : Probabilidad 0.09040 : Información 3.46761
#  ('BROADCAST', 2054) : Probabilidad 0.00565 : Información 7.46761
# Entropia de la fuente 1.10456 con 177 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73596 : Información 0.44231
#  ('BROADCAST', 2048) : Probabilidad 0.16854 : Información 2.56884
#  ('UNICAST', 2054) : Probabilidad 0.08989 : Información 3.47573
#  ('BROADCAST', 2054) : Probabilidad 0.00562 : Información 7.47573
# Entropia de la fuente 1.11290 con 178 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73743 : Información 0.43942
#  ('BROADCAST', 2048) : Probabilidad 0.16760 : Información 2.57693
#  ('UNICAST', 2054) : Probabilidad 0.08939 : Información 3.48382
#  ('BROADCAST', 2054) : Probabilidad 0.00559 : Información 7.48382
# Entropia de la fuente 1.10914 con 179 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73889 : Información 0.43657
#  ('BROADCAST', 2048) : Probabilidad 0.16667 : Información 2.58496
#  ('UNICAST', 2054) : Probabilidad 0.08889 : Información 3.49185
#  ('BROADCAST', 2054) : Probabilidad 0.00556 : Información 7.49185
# Entropia de la fuente 1.10541 con 180 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73481 : Información 0.44456
#  ('BROADCAST', 2048) : Probabilidad 0.17127 : Información 2.54565
#  ('UNICAST', 2054) : Probabilidad 0.08840 : Información 3.49985
#  ('BROADCAST', 2054) : Probabilidad 0.00552 : Información 7.49985
# Entropia de la fuente 1.11348 con 181 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73626 : Información 0.44171
#  ('BROADCAST', 2048) : Probabilidad 0.17033 : Información 2.55360
#  ('UNICAST', 2054) : Probabilidad 0.08791 : Información 3.50779
#  ('BROADCAST', 2054) : Probabilidad 0.00549 : Información 7.50779
# Entropia de la fuente 1.10979 con 182 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.73224 : Información 0.44961
#  ('BROADCAST', 2048) : Probabilidad 0.17486 : Información 2.51570
#  ('UNICAST', 2054) : Probabilidad 0.08743 : Información 3.51570
#  ('BROADCAST', 2054) : Probabilidad 0.00546 : Información 7.51570
# Entropia de la fuente 1.11758 con 183 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.72826 : Información 0.45747
#  ('BROADCAST', 2048) : Probabilidad 0.17935 : Información 2.47917
#  ('UNICAST', 2054) : Probabilidad 0.08696 : Información 3.52356
#  ('BROADCAST', 2054) : Probabilidad 0.00543 : Información 7.52356
# Entropia de la fuente 1.12508 con 184 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.72973 : Información 0.45457
#  ('BROADCAST', 2048) : Probabilidad 0.17838 : Información 2.48699
#  ('UNICAST', 2054) : Probabilidad 0.08649 : Información 3.53138
#  ('BROADCAST', 2054) : Probabilidad 0.00541 : Información 7.53138
# Entropia de la fuente 1.12146 con 185 paquetes leidos
#
# ...
#  ('BROADCAST', 2054) : Probabilidad 0.00102 : Información 9.94398
# Entropia de la fuente 0.49545 con 2955 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91712 : Información 0.12482
#  ('BROADCAST', 2048) : Probabilidad 0.05277 : Información 4.24403
#  ('UNICAST', 2054) : Probabilidad 0.02909 : Información 5.10317
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94447
# Entropia de la fuente 0.49701 con 2956 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91715 : Información 0.12478
#  ('BROADCAST', 2048) : Probabilidad 0.05276 : Información 4.24452
#  ('UNICAST', 2054) : Probabilidad 0.02908 : Información 5.10365
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94496
# Entropia de la fuente 0.49689 con 2957 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91717 : Información 0.12473
#  ('BROADCAST', 2048) : Probabilidad 0.05274 : Información 4.24500
#  ('UNICAST', 2054) : Probabilidad 0.02907 : Información 5.10414
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94544
# Entropia de la fuente 0.49676 con 2958 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91686 : Información 0.12522
#  ('BROADCAST', 2048) : Probabilidad 0.05306 : Información 4.23627
#  ('UNICAST', 2054) : Probabilidad 0.02906 : Información 5.10463
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94593
# Entropia de la fuente 0.49802 con 2959 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91689 : Información 0.12518
#  ('BROADCAST', 2048) : Probabilidad 0.05304 : Información 4.23676
#  ('UNICAST', 2054) : Probabilidad 0.02905 : Información 5.10512
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94642
# Entropia de la fuente 0.49790 con 2960 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91692 : Información 0.12513
#  ('BROADCAST', 2048) : Probabilidad 0.05302 : Información 4.23725
#  ('UNICAST', 2054) : Probabilidad 0.02904 : Información 5.10560
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94691
# Entropia de la fuente 0.49777 con 2961 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91695 : Información 0.12509
#  ('BROADCAST', 2048) : Probabilidad 0.05300 : Información 4.23774
#  ('UNICAST', 2054) : Probabilidad 0.02903 : Información 5.10609
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94739
# Entropia de la fuente 0.49765 con 2962 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91698 : Información 0.12504
#  ('BROADCAST', 2048) : Probabilidad 0.05299 : Información 4.23822
#  ('UNICAST', 2054) : Probabilidad 0.02902 : Información 5.10658
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94788
# Entropia de la fuente 0.49752 con 2963 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91700 : Información 0.12500
#  ('BROADCAST', 2048) : Probabilidad 0.05297 : Información 4.23871
#  ('UNICAST', 2054) : Probabilidad 0.02901 : Información 5.10706
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94837
# Entropia de la fuente 0.49740 con 2964 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91669 : Información 0.12549
#  ('BROADCAST', 2048) : Probabilidad 0.05329 : Información 4.23004
#  ('UNICAST', 2054) : Probabilidad 0.02901 : Información 5.10755
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94885
# Entropia de la fuente 0.49866 con 2965 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91672 : Información 0.12544
#  ('BROADCAST', 2048) : Probabilidad 0.05327 : Información 4.23052
#  ('UNICAST', 2054) : Probabilidad 0.02900 : Información 5.10804
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94934
# Entropia de la fuente 0.49853 con 2966 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91675 : Información 0.12540
#  ('BROADCAST', 2048) : Probabilidad 0.05325 : Información 4.23101
#  ('UNICAST', 2054) : Probabilidad 0.02899 : Información 5.10852
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.94983
# Entropia de la fuente 0.49840 con 2967 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91678 : Información 0.12535
#  ('BROADCAST', 2048) : Probabilidad 0.05323 : Información 4.23149
#  ('UNICAST', 2054) : Probabilidad 0.02898 : Información 5.10901
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.95031
# Entropia de la fuente 0.49828 con 2968 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91681 : Información 0.12531
#  ('BROADCAST', 2048) : Probabilidad 0.05322 : Información 4.23198
#  ('UNICAST', 2054) : Probabilidad 0.02897 : Información 5.10950
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.95080
# Entropia de la fuente 0.49815 con 2969 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91684 : Información 0.12527
#  ('BROADCAST', 2048) : Probabilidad 0.05320 : Información 4.23247
#  ('UNICAST', 2054) : Probabilidad 0.02896 : Información 5.10998
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.95128
# Entropia de la fuente 0.49803 con 2970 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91686 : Información 0.12522
#  ('BROADCAST', 2048) : Probabilidad 0.05318 : Información 4.23295
#  ('UNICAST', 2054) : Probabilidad 0.02895 : Información 5.11047
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.95177
# Entropia de la fuente 0.49790 con 2971 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91689 : Información 0.12518
#  ('BROADCAST', 2048) : Probabilidad 0.05316 : Información 4.23344
#  ('UNICAST', 2054) : Probabilidad 0.02894 : Información 5.11095
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.95226
# Entropia de la fuente 0.49778 con 2972 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.91692 : Información 0.12513
#  ('BROADCAST', 2048) : Probabilidad 0.05314 : Información 4.23392
#  ('UNICAST', 2054) : Probabilidad 0.02893 : Información 5.11144
#  ('BROADCAST', 2054) : Probabilidad 0.00101 : Información 9.95274
# Entropia de la fuente 0.49765 con 2973 paquetes leidos
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Entropia de la fuente 0.65471 con 4478 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88301 : Información 0.17950
#  ('BROADCAST', 2048) : Probabilidad 0.07435 : Información 3.74958
#  ('UNICAST', 2054) : Probabilidad 0.03818 : Información 4.71111
#  ('UNICAST', 34525) : Probabilidad 0.00335 : Información 8.22207
#  ('BROADCAST', 2054) : Probabilidad 0.00112 : Información 9.80703
# Entropia de la fuente 0.65561 con 4479 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88281 : Información 0.17982
#  ('BROADCAST', 2048) : Probabilidad 0.07433 : Información 3.74990
#  ('UNICAST', 2054) : Probabilidad 0.03839 : Información 4.70302
#  ('UNICAST', 34525) : Probabilidad 0.00335 : Información 8.22239
#  ('BROADCAST', 2054) : Probabilidad 0.00112 : Información 9.80735
# Entropia de la fuente 0.65652 con 4480 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88284 : Información 0.17978
#  ('BROADCAST', 2048) : Probabilidad 0.07431 : Información 3.75023
#  ('UNICAST', 2054) : Probabilidad 0.03838 : Información 4.70334
#  ('UNICAST', 34525) : Probabilidad 0.00335 : Información 8.22271
#  ('BROADCAST', 2054) : Probabilidad 0.00112 : Información 9.80768
# Entropia de la fuente 0.65641 con 4481 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88264 : Información 0.18010
#  ('BROADCAST', 2048) : Probabilidad 0.07452 : Información 3.74622
#  ('UNICAST', 2054) : Probabilidad 0.03838 : Información 4.70366
#  ('UNICAST', 34525) : Probabilidad 0.00335 : Información 8.22304
#  ('BROADCAST', 2054) : Probabilidad 0.00112 : Información 9.80800
# Entropia de la fuente 0.65710 con 4482 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88244 : Información 0.18042
#  ('BROADCAST', 2048) : Probabilidad 0.07473 : Información 3.74223
#  ('UNICAST', 2054) : Probabilidad 0.03837 : Información 4.70398
#  ('UNICAST', 34525) : Probabilidad 0.00335 : Información 8.22336
#  ('BROADCAST', 2054) : Probabilidad 0.00112 : Información 9.80832
# Entropia de la fuente 0.65779 con 4483 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88247 : Información 0.18038
#  ('BROADCAST', 2048) : Probabilidad 0.07471 : Información 3.74255
#  ('UNICAST', 2054) : Probabilidad 0.03836 : Información 4.70431
#  ('UNICAST', 34525) : Probabilidad 0.00335 : Información 8.22368
#  ('BROADCAST', 2054) : Probabilidad 0.00112 : Información 9.80864
# Entropia de la fuente 0.65768 con 4484 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88227 : Información 0.18070
#  ('BROADCAST', 2048) : Probabilidad 0.07492 : Información 3.73857
#  ('UNICAST', 2054) : Probabilidad 0.03835 : Información 4.70463
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22400
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.80896
# Entropia de la fuente 0.65837 con 4485 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88230 : Información 0.18066
#  ('BROADCAST', 2048) : Probabilidad 0.07490 : Información 3.73890
#  ('UNICAST', 2054) : Probabilidad 0.03834 : Información 4.70495
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22432
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.80929
# Entropia de la fuente 0.65826 con 4486 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88233 : Información 0.18062
#  ('BROADCAST', 2048) : Probabilidad 0.07488 : Información 3.73922
#  ('UNICAST', 2054) : Probabilidad 0.03833 : Información 4.70527
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22464
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.80961
# Entropia de la fuente 0.65816 con 4487 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88235 : Información 0.18057
#  ('BROADCAST', 2048) : Probabilidad 0.07487 : Información 3.73954
#  ('UNICAST', 2054) : Probabilidad 0.03832 : Información 4.70559
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22497
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.80993
# Entropia de la fuente 0.65805 con 4488 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88238 : Información 0.18053
#  ('BROADCAST', 2048) : Probabilidad 0.07485 : Información 3.73986
#  ('UNICAST', 2054) : Probabilidad 0.03832 : Información 4.70591
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22529
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81025
# Entropia de la fuente 0.65795 con 4489 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88241 : Información 0.18049
#  ('BROADCAST', 2048) : Probabilidad 0.07483 : Información 3.74018
#  ('UNICAST', 2054) : Probabilidad 0.03831 : Información 4.70623
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22561
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81057
# Entropia de la fuente 0.65784 con 4490 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88221 : Información 0.18081
#  ('BROADCAST', 2048) : Probabilidad 0.07504 : Información 3.73622
#  ('UNICAST', 2054) : Probabilidad 0.03830 : Información 4.70656
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22593
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81089
# Entropia de la fuente 0.65853 con 4491 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88201 : Información 0.18113
#  ('BROADCAST', 2048) : Probabilidad 0.07502 : Información 3.73654
#  ('UNICAST', 2054) : Probabilidad 0.03851 : Información 4.69851
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22625
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81121
# Entropia de la fuente 0.65943 con 4492 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88182 : Información 0.18145
#  ('BROADCAST', 2048) : Probabilidad 0.07501 : Información 3.73686
#  ('UNICAST', 2054) : Probabilidad 0.03873 : Información 4.69052
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22657
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81154
# Entropia de la fuente 0.66032 con 4493 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88184 : Información 0.18141
#  ('BROADCAST', 2048) : Probabilidad 0.07499 : Información 3.73718
#  ('UNICAST', 2054) : Probabilidad 0.03872 : Información 4.69084
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22689
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81186
# Entropia de la fuente 0.66022 con 4494 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88187 : Información 0.18136
#  ('BROADCAST', 2048) : Probabilidad 0.07497 : Información 3.73750
#  ('UNICAST', 2054) : Probabilidad 0.03871 : Información 4.69116
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22721
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81218
# Entropia de la fuente 0.66011 con 4495 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88167 : Información 0.18169
#  ('BROADCAST', 2048) : Probabilidad 0.07518 : Información 3.73355
#  ('UNICAST', 2054) : Probabilidad 0.03870 : Información 4.69148
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22754
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81250
# Entropia de la fuente 0.66079 con 4496 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88170 : Información 0.18164
#  ('BROADCAST', 2048) : Probabilidad 0.07516 : Información 3.73387
#  ('UNICAST', 2054) : Probabilidad 0.03869 : Información 4.69180
#  ('UNICAST', 34525) : Probabilidad 0.00334 : Información 8.22786
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81282
# Entropia de la fuente 0.66069 con 4497 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88150 : Información 0.18196
#  ('BROADCAST', 2048) : Probabilidad 0.07537 : Información 3.72993
#  ('UNICAST', 2054) : Probabilidad 0.03868 : Información 4.69212
#  ('UNICAST', 34525) : Probabilidad 0.00333 : Información 8.22818
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81314
# Entropia de la fuente 0.66137 con 4498 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88153 : Información 0.18192
#  ('BROADCAST', 2048) : Probabilidad 0.07535 : Información 3.73025
#  ('UNICAST', 2054) : Probabilidad 0.03868 : Información 4.69245
#  ('UNICAST', 34525) : Probabilidad 0.00333 : Información 8.22850
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81346
# Entropia de la fuente 0.66126 con 4499 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88156 : Información 0.18188
#  ('BROADCAST', 2048) : Probabilidad 0.07533 : Información 3.73057
#  ('UNICAST', 2054) : Probabilidad 0.03867 : Información 4.69277
#  ('UNICAST', 34525) : Probabilidad 0.00333 : Información 8.22882
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81378
# Entropia de la fuente 0.66116 con 4500 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88158 : Información 0.18183
#  ('BROADCAST', 2048) : Probabilidad 0.07532 : Información 3.73089
#  ('UNICAST', 2054) : Probabilidad 0.03866 : Información 4.69309
#  ('UNICAST', 34525) : Probabilidad 0.00333 : Información 8.22914
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81410
# Entropia de la fuente 0.66105 con 4501 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88161 : Información 0.18179
#  ('BROADCAST', 2048) : Probabilidad 0.07530 : Información 3.73121
#  ('UNICAST', 2054) : Probabilidad 0.03865 : Información 4.69341
#  ('UNICAST', 34525) : Probabilidad 0.00333 : Información 8.22946
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81442
# Entropia de la fuente 0.66094 con 4502 paquetes leidos
#
#  ('UNICAST', 2048) : Probabilidad 0.88141 : Información 0.18211
#  ('BROADCAST', 2048) : Probabilidad 0.07528 : Información 3.73153
#  ('UNICAST', 2054) : Probabilidad 0.03864 : Información 4.69373
#  ('UNICAST', 34525) : Probabilidad 0.00355 : Información 8.13667
#  ('BROADCAST', 2054) : Probabilidad 0.00111 : Información 9.81474
# Entropia de la fuente 0.66262 con 4503 paquetes leidos

# %%
mostrar_fuente(S1)
# Out:
#  ('UNICAST', 2048) : Probabilidad 0.98902 : Información 0.01593
#  ('BROADCAST', 2048) : Probabilidad 0.00686 : Información 7.18758
#  ('UNICAST', 2054) : Probabilidad 0.00352 : Información 8.15021
#  ('UNICAST', 34525) : Probabilidad 0.00050 : Información 10.96578
#  ('BROADCAST', 2054) : Probabilidad 0.00010 : Información 13.28771
# Entropia de la fuente 0.10056 con 50000 paquetes leidos

# %%
def entropiaMaxima(fuente):
    N = sum(fuente.values())
    return math.log2(N)

# %%
entropiaMaxima(S1)
# Out:
# 15.609640474436812

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\valen\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
simbolos = sorted(S1.items(), key=lambda x: -x[1])
countBroad = 0
countUni = 0
for d,k in simbolos:    
    if d[0] == 'BROADCAST':
        countBroad += k        
    else:
        countUni += k
explode = (0, 0.5)

plt.pie([countBroad,countUni], explode=explode, labels=['BROADCAST','UNICAST'], autopct='%1.1f%%',
       shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2acbf1e2390>,
#   <matplotlib.patches.Wedge at 0x2acbf1f0150>],
#  [Text(1.0997370557973554, 0.02405011655199186, 'BROADCAST'),
#   Text(-1.599617532941747, -0.034982114077896, 'UNICAST')],
#  [Text(0.5998565758894665, 0.013118245391995558, '0.7%'),
#   Text(-1.0997370538974511, -0.024050203428553494, '99.3%')])

# %%
protocols = []
K = []
percent=[]
for p,k in simbolos:
    protocols.append((p))
    K.append(k)
    percent.append(str((k)/(100*len(simbolos))) + '%')
explode=(0,0.1,0.2,0.3,0.4)

patches, texts = plt.pie(K,explode=explode)

zipped= zip(protocols,percent)
plt.legend(patches, zipped, loc="best")

# %%
import socket
def proto_name_by_num(proto_num):
    for name,num in vars(socket).items():
        if name.startswith("IPPROTO") and proto_num == num:
            return name[8:]
    return "Protocol not found"

# %%
protocols = []
K = []
percent=[]
for p,k in simbolos:
    protocols.append((p[0],proto_name_by_num(p[1])))
    K.append(k)
    percent.append(str((k)/(100*len(simbolos))) + '%')
explode=(0,0.1,0.2,0.3,0.4)

patches, texts = plt.pie(K,explode=explode)

zipped= zip(protocols,percent)
plt.legend(patches, zipped, loc="best")

# %%
ls()
# Out:
# AD_AND_OR  : None
# AD_KDCIssued : None
# AH         : AH
# AKMSuite   : AKM suite
# ARP        : ARP
# ASN1P_INTEGER : None
# ASN1P_OID  : None
# ASN1P_PRIVSEQ : None
# ASN1_Packet : None
# ASN1_Packet : None
# ATT_Error_Response : Error Response
# ATT_Exchange_MTU_Request : Exchange MTU Request
# ATT_Exchange_MTU_Response : Exchange MTU Response
# ATT_Execute_Write_Request : Execute Write Request
# ATT_Execute_Write_Response : Execute Write Response
# ATT_Find_By_Type_Value_Request : Find By Type Value Request
# ATT_Find_By_Type_Value_Response : Find By Type Value Response
# ATT_Find_Information_Request : Find Information Request
# ATT_Find_Information_Response : Find Information Response
# ATT_Handle : ATT Short Handle
# ATT_Handle_UUID128 : ATT Handle (UUID 128)
# ATT_Handle_Value_Indication : Handle Value Indication
# ATT_Handle_Value_Notification : Handle Value Notification
# ATT_Handle_Variable : None
# ATT_Hdr    : ATT header
# ATT_Prepare_Write_Request : Prepare Write Request
# ATT_Prepare_Write_Response : Prepare Write Response
# ATT_Read_Blob_Request : Read Blob Request
# ATT_Read_Blob_Response : Read Blob Response
# ATT_Read_By_Group_Type_Request : Read By Group Type Request
# ATT_Read_By_Group_Type_Response : Read By Group Type Response
# ATT_Read_By_Type_Request : Read By Type Request
# ATT_Read_By_Type_Request_128bit : Read By Type Request
# ATT_Read_By_Type_Response : Read By Type Response
# ATT_Read_Multiple_Request : Read Multiple Request
# ATT_Read_Multiple_Response : Read Multiple Response
# ATT_Read_Request : Read Request
# ATT_Read_Response : Read Response
# ATT_Write_Command : Write Request
# ATT_Write_Request : Write Request
# ATT_Write_Response : Write Response
# AV_PAIR    : NTLM AV Pair
# AttributeValueAssertion : None
# AuthorizationData : None
# AuthorizationDataItem : None
# BOOTP      : BOOTP
# BTLE       : BT4LE
# BTLE_ADV   : BTLE advertising header
# BTLE_ADV_DIRECT_IND : BTLE ADV_DIRECT_IND
# BTLE_ADV_IND : BTLE ADV_IND
# BTLE_ADV_NONCONN_IND : BTLE ADV_NONCONN_IND
# BTLE_ADV_SCAN_IND : BTLE ADV_SCAN_IND
# BTLE_CONNECT_REQ : BTLE connect request
# BTLE_CTRL  : BTLE_CTRL
# BTLE_DATA  : BTLE data header
# BTLE_EMPTY_PDU : Empty data PDU
# BTLE_PPI   : BTLE PPI header
# BTLE_RF    : BTLE RF info header
# BTLE_SCAN_REQ : BTLE scan request
# BTLE_SCAN_RSP : BTLE scan response
# CLAIMS_ARRAY : None
# CLAIMS_SET : None
# CLAIMS_SET_METADATA : None
# CLAIMS_SET_WRAP : None
# CLAIM_ENTRY : None
# CLDAP      : None
# CYPHER_BLOCK : None
# CommonAuthVerifier : Common Authentication Verifier (sec_trailer)
# CookedLinux : cooked linux
# CookedLinuxV2 : cooked linux v2
# DHCP       : DHCP options
# DHCP6      : DHCPv6 Generic Message
# DHCP6OptAuth : DHCP6 Option - Authentication
# DHCP6OptBCMCSDomains : DHCP6 Option - BCMCS Domain Name List
# DHCP6OptBCMCSServers : DHCP6 Option - BCMCS Addresses List
# DHCP6OptBootFileUrl : DHCP6 Boot File URL Option
# DHCP6OptClientArchType : DHCP6 Client System Architecture Type Option
# DHCP6OptClientFQDN : DHCP6 Option - Client FQDN
# DHCP6OptClientId : DHCP6 Client Identifier Option
# DHCP6OptClientLinkLayerAddr : DHCP6 Option - Client Link Layer address
# DHCP6OptClientNetworkInterId : DHCP6 Client Network Interface Identifier Option
# DHCP6OptDNSDomains : DHCP6 Option - Domain Search List option
# DHCP6OptDNSServers : DHCP6 Option - DNS Recursive Name Server
# DHCP6OptERPDomain : DHCP6 Option - ERP Domain Name List
# DHCP6OptElapsedTime : DHCP6 Elapsed Time Option
# DHCP6OptGeoConf : DHCP6 Option - Civic Location
# DHCP6OptGeoConfElement : None
# DHCP6OptIAAddress : DHCP6 IA Address Option (IA_TA or IA_NA suboption)
# DHCP6OptIAPrefix : DHCP6 Option - IA Prefix option
# DHCP6OptIA_NA : DHCP6 Identity Association for Non-temporary Addresses Option
# DHCP6OptIA_PD : DHCP6 Option - Identity Association for Prefix Delegation
# DHCP6OptIA_TA : DHCP6 Identity Association for Temporary Addresses Option
# DHCP6OptIfaceId : DHCP6 Interface-Id Option
# DHCP6OptInfoRefreshTime : DHCP6 Option - Information Refresh Time
# DHCP6OptLQClientLink : DHCP6 Client Link Option
# DHCP6OptMudUrl : DHCP6 Option - MUD URL
# DHCP6OptNISDomain : DHCP6 Option - NIS Domain Name
# DHCP6OptNISPDomain : DHCP6 Option - NIS+ Domain Name
# DHCP6OptNISPServers : DHCP6 Option - NIS+ Servers
# DHCP6OptNISServers : DHCP6 Option - NIS Servers
# DHCP6OptNewPOSIXTimeZone : DHCP6 POSIX Timezone Option
# DHCP6OptNewTZDBTimeZone : DHCP6 TZDB Timezone Option
# DHCP6OptOptReq : DHCP6 Option Request Option
# DHCP6OptPanaAuthAgent : DHCP6 PANA Authentication Agent Option
# DHCP6OptPref : DHCP6 Preference Option
# DHCP6OptRapidCommit : DHCP6 Rapid Commit Option
# DHCP6OptReconfAccept : DHCP6 Reconfigure Accept Option
# DHCP6OptReconfMsg : DHCP6 Reconfigure Message Option
# DHCP6OptRelayAgentERO : DHCP6 Option - RelayRequest Option
# DHCP6OptRelayMsg : DHCP6 Relay Message Option
# DHCP6OptRelaySuppliedOpt : DHCP6 Relay-Supplied Options Option
# DHCP6OptRemoteID : DHCP6 Option - Relay Agent Remote-ID
# DHCP6OptSIPDomains : DHCP6 Option - SIP Servers Domain Name List
# DHCP6OptSIPServers : DHCP6 Option - SIP Servers IPv6 Address List
# DHCP6OptSNTPServers : DHCP6 option - SNTP Servers
# DHCP6OptServerId : DHCP6 Server Identifier Option
# DHCP6OptServerUnicast : DHCP6 Server Unicast Option
# DHCP6OptStatusCode : DHCP6 Status Code Option
# DHCP6OptSubscriberID : DHCP6 Option - Subscriber ID
# DHCP6OptUnknown : Unknown DHCPv6 Option
# DHCP6OptUserClass : DHCP6 User Class Option
# DHCP6OptVSS : DHCP6 Option - Virtual Subnet Selection
# DHCP6OptVendorClass : DHCP6 Vendor Class Option
# DHCP6OptVendorSpecificInfo : DHCP6 Vendor-specific Information Option
# DHCP6_Advertise : DHCPv6 Advertise Message
# DHCP6_Confirm : DHCPv6 Confirm Message
# DHCP6_Decline : DHCPv6 Decline Message
# DHCP6_InfoRequest : DHCPv6 Information Request Message
# DHCP6_Rebind : DHCPv6 Rebind Message
# DHCP6_Reconf : DHCPv6 Reconfigure Message
# DHCP6_RelayForward : DHCPv6 Relay Forward Message (Relay Agent/Server Message)
# DHCP6_RelayReply : DHCPv6 Relay Reply Message (Relay Agent/Server Message)
# DHCP6_Release : DHCPv6 Release Message
# DHCP6_Renew : DHCPv6 Renew Message
# DHCP6_Reply : DHCPv6 Reply Message
# DHCP6_Request : DHCPv6 Request Message
# DHCP6_Solicit : DHCPv6 Solicit Message
# DHRepInfo  : None
# DIR_PPP    : None
# DNS        : DNS
# DNSQR      : DNS Question Record
# DNSRR      : DNS Resource Record
# DNSRRDLV   : DNS DLV Resource Record
# DNSRRDNSKEY : DNS DNSKEY Resource Record
# DNSRRDS    : DNS DS Resource Record
# DNSRRMX    : DNS MX Resource Record
# DNSRRNSEC  : DNS NSEC Resource Record
# DNSRRNSEC3 : DNS NSEC3 Resource Record
# DNSRRNSEC3PARAM : DNS NSEC3PARAM Resource Record
# DNSRROPT   : DNS OPT Resource Record
# DNSRRRSIG  : DNS RRSIG Resource Record
# DNSRRSOA   : DNS SOA Resource Record
# DNSRRSRV   : DNS SRV Resource Record
# DNSRRTSIG  : DNS TSIG Resource Record
# DUID_EN    : DUID - Assigned by Vendor Based on Enterprise Number
# DUID_LL    : DUID - Based on Link-layer Address
# DUID_LLT   : DUID - Link-layer address plus time
# DUID_UUID  : DUID - Based on UUID
# DataPacket : Data Packet
# DceRpc     : None
# DceRpc4    : DCE/RPC v4
# DceRpc4Payload : None
# DceRpc5    : DCE/RPC v5
# DceRpc5AbstractSyntax : Presentation Syntax (p_syntax_id_t)
# DceRpc5AlterContext : DCE/RPC v5 - AlterContext
# DceRpc5AlterContextResp : DCE/RPC v5 - AlterContextResp
# DceRpc5Auth3 : DCE/RPC v5 - Auth3
# DceRpc5Bind : DCE/RPC v5 - Bind
# DceRpc5BindAck : DCE/RPC v5 - Bind Ack
# DceRpc5BindNak : DCE/RPC v5 - Bind Nak
# DceRpc5Context : Presentation Context (p_cont_elem_t)
# DceRpc5Fault : DCE/RPC v5 - Fault
# DceRpc5PortAny : Port Any (port_any_t)
# DceRpc5Request : DCE/RPC v5 - Request
# DceRpc5Response : DCE/RPC v5 - Response
# DceRpc5Result : Context negotiation Result
# DceRpc5TransferSyntax : Presentation Transfer Syntax (p_syntax_id_t)
# DceRpc5Version : version_t
# Dot11      : 802.11
# Dot11ATIM  : 802.11 ATIM
# Dot11Ack   : 802.11 Ack packet
# Dot11AssoReq : 802.11 Association Request
# Dot11AssoResp : 802.11 Association Response
# Dot11Auth  : 802.11 Authentication
# Dot11Beacon : 802.11 Beacon
# Dot11CCMP  : 802.11 CCMP packet
# Dot11Deauth : 802.11 Deauthentication
# Dot11Disas : 802.11 Disassociation
# Dot11Elt   : 802.11 Information Element
# Dot11EltCountry : 802.11 Country
# Dot11EltCountryConstraintTriplet : 802.11 Country Constraint Triplet
# Dot11EltDSSSet : 802.11 DSSS Parameter Set
# Dot11EltERP : 802.11 ERP
# Dot11EltHTCapabilities : 802.11 HT Capabilities
# Dot11EltMicrosoftWPA : 802.11 Microsoft WPA
# Dot11EltRSN : 802.11 RSN information
# Dot11EltRates : 802.11 Rates
# Dot11EltVendorSpecific : 802.11 Vendor Specific
# Dot11Encrypted : 802.11 Encrypted (unknown algorithm)
# Dot11FCS   : 802.11-FCS
# Dot11ProbeReq : 802.11 Probe Request
# Dot11ProbeResp : 802.11 Probe Response
# Dot11QoS   : 802.11 QoS
# Dot11ReassoReq : 802.11 Reassociation Request
# Dot11ReassoResp : 802.11 Reassociation Response
# Dot11TKIP  : 802.11 TKIP packet
# Dot11WEP   : 802.11 WEP packet
# Dot15d4    : 802.15.4
# Dot15d4Ack : 802.15.4 Ack
# Dot15d4AuxSecurityHeader : 802.15.4 Auxiliary Security Header
# Dot15d4Beacon : 802.15.4 Beacon
# Dot15d4Cmd : 802.15.4 Command
# Dot15d4CmdAssocReq : 802.15.4 Association Request Payload
# Dot15d4CmdAssocResp : 802.15.4 Association Response Payload
# Dot15d4CmdCoordRealign : 802.15.4 Coordinator Realign Command
# Dot15d4CmdCoordRealignPage : 802.15.4 Coordinator Realign Page
# Dot15d4CmdDisassociation : 802.15.4 Disassociation Notification Payload
# Dot15d4CmdGTSReq : 802.15.4 GTS request command
# Dot15d4Data : 802.15.4 Data
# Dot15d4FCS : 802.15.4 - FCS
# Dot1AD     : 802_1AD
# Dot1Q      : 802.1Q
# Dot3       : 802.3
# EAP        : EAP
# EAPOL      : EAPOL
# EAP_FAST   : EAP-FAST
# EAP_MD5    : EAP-MD5
# EAP_PEAP   : PEAP
# EAP_TLS    : EAP-TLS
# EAP_TTLS   : EAP-TTLS
# ECCurve    : None
# ECDSAPrivateKey : None
# ECDSAPrivateKey_OpenSSL : ECDSA Params + Private Key
# ECDSAPublicKey : None
# ECDSASignature : None
# ECFieldID  : None
# ECParameters : None
# ECSpecifiedDomain : None
# EDNS0ClientSubnet : DNS EDNS0 Client Subnet
# EDNS0TLV   : DNS EDNS0 TLV
# EIR_CompleteList128BitServiceUUIDs : Complete list of 128-bit service UUIDs
# EIR_CompleteList16BitServiceUUIDs : Complete list of 16-bit service UUIDs
# EIR_CompleteLocalName : Complete Local Name
# EIR_Device_ID : Device ID
# EIR_Element : EIR Element
# EIR_Flags  : Flags
# EIR_Hdr    : EIR Header
# EIR_IncompleteList128BitServiceUUIDs : Incomplete list of 128-bit service UUIDs
# EIR_IncompleteList16BitServiceUUIDs : Incomplete list of 16-bit service UUIDs
# EIR_Manufacturer_Specific_Data : EIR Manufacturer Specific Data
# EIR_Raw    : EIR Raw
# EIR_ServiceData16BitUUID : EIR Service Data - 16-bit UUID
# EIR_ShortenedLocalName : Shortened Local Name
# EIR_TX_Power_Level : TX Power Level
# EPacket    : None
# ESP        : ESP
# ETYPE_INFO : None
# ETYPE_INFO2 : None
# ETYPE_INFO_ENTRY : None
# ETYPE_INFO_ENTRY2 : None
# EncASRepPart : None
# EncKeyPack : None
# EncTGSRepPart : None
# EncTicketPart : None
# EncryptedData : None
# EncryptionKey : None
# EndpointFlagsPacket : RTPS Endpoint Builtin Endpoint Flags
# Ether      : Ethernet
# EtherCat   : None
# EtherCatAPRD : None
# EtherCatAPRW : None
# EtherCatAPWR : None
# EtherCatARMW : None
# EtherCatBRD : None
# EtherCatBRW : None
# EtherCatBWR : None
# EtherCatFPRD : None
# EtherCatFPRW : None
# EtherCatFPWR : None
# EtherCatFRMW : None
# EtherCatLRD : None
# EtherCatLRW : None
# EtherCatLWR : None
# EtherCatType12DLPDU : None
# ExternalPrincipalIdentifier : None
# FILETIME   : None
# FILE_GET_QUOTA_INFORMATION : None
# FILE_ID_BOTH_DIR_INFORMATION : None
# FileEaInformation : None
# FileFsAttributeInformation : None
# FileFsSizeInformation : None
# FileFsVolumeInformation : None
# FileIdBothDirectoryInformation : None
# FileInternalInformation : None
# FileNetworkOpenInformation : None
# FileStandardInformation : None
# FileStreamInformation : None
# GPRS       : GPRSdummy
# GRE        : GRE
# GRE_PPTP   : GRE PPTP
# GRErouting : GRE routing information
# GSSAPI_BLOB : None
# GUIDPacket : RTPS GUID
# GUIDPrefixPacket : RTPS GUID Prefix
# HAO        : Home Address Option
# HBHOptUnknown : Scapy6 Unknown Option
# HCI_ACL_Hdr : HCI ACL header
# HCI_Cmd_Complete_LE_Read_White_List_Size : LE Read White List Size
# HCI_Cmd_Complete_Read_BD_Addr : Read BD Addr
# HCI_Cmd_Connect_Accept_Timeout : Connection Attempt Timeout
# HCI_Cmd_Disconnect : Disconnect
# HCI_Cmd_LE_Add_Device_To_White_List : LE Add Device to White List
# HCI_Cmd_LE_Clear_White_List : LE Clear White List
# HCI_Cmd_LE_Connection_Update : LE Connection Update
# HCI_Cmd_LE_Create_Connection : LE Create Connection
# HCI_Cmd_LE_Create_Connection_Cancel : LE Create Connection Cancel
# HCI_Cmd_LE_Host_Supported : LE Host Supported
# HCI_Cmd_LE_Long_Term_Key_Request_Negative_Reply : LE Long Term Key Request Negative Reply
# HCI_Cmd_LE_Long_Term_Key_Request_Reply : LE Long Term Key Request Reply
# HCI_Cmd_LE_Read_Buffer_Size : LE Read Buffer Size
# HCI_Cmd_LE_Read_Remote_Used_Features : LE Read Remote Used Features
# HCI_Cmd_LE_Read_White_List_Size : LE Read White List Size
# HCI_Cmd_LE_Remove_Device_From_White_List : LE Remove Device from White List
# HCI_Cmd_LE_Set_Advertise_Enable : LE Set Advertise Enable
# HCI_Cmd_LE_Set_Advertising_Data : LE Set Advertising Data
# HCI_Cmd_LE_Set_Advertising_Parameters : LE Set Advertising Parameters
# HCI_Cmd_LE_Set_Random_Address : LE Set Random Address
# HCI_Cmd_LE_Set_Scan_Enable : LE Set Scan Enable
# HCI_Cmd_LE_Set_Scan_Parameters : LE Set Scan Parameters
# HCI_Cmd_LE_Set_Scan_Response_Data : LE Set Scan Response Data
# HCI_Cmd_LE_Start_Encryption_Request : LE Start Encryption
# HCI_Cmd_Read_BD_Addr : Read BD Addr
# HCI_Cmd_Reset : Reset
# HCI_Cmd_Set_Event_Filter : Set Event Filter
# HCI_Cmd_Set_Event_Mask : Set Event Mask
# HCI_Cmd_Write_Extended_Inquiry_Response : Write Extended Inquiry Response
# HCI_Cmd_Write_Local_Name : None
# HCI_Command_Hdr : HCI Command header
# HCI_Event_Command_Complete : Command Complete
# HCI_Event_Command_Status : Command Status
# HCI_Event_Disconnection_Complete : Disconnection Complete
# HCI_Event_Encryption_Change : Encryption Change
# HCI_Event_Hdr : HCI Event header
# HCI_Event_LE_Meta : LE Meta
# HCI_Event_Number_Of_Completed_Packets : Number Of Completed Packets
# HCI_Hdr    : HCI header
# HCI_LE_Meta_Advertising_Report : Advertising Report
# HCI_LE_Meta_Advertising_Reports : Advertising Reports
# HCI_LE_Meta_Connection_Complete : Connection Complete
# HCI_LE_Meta_Connection_Update_Complete : Connection Update Complete
# HCI_LE_Meta_Long_Term_Key_Request : Long Term Key Request
# HCI_PHDR_Hdr : HCI PHDR transport layer
# HDLC       : None
# HSRP       : HSRP
# HSRPmd5    : HSRP MD5 Authentication
# HostAddress : None
# ICMP       : ICMP
# ICMPerror  : ICMP in ICMP
# ICMPv6DestUnreach : ICMPv6 Destination Unreachable
# ICMPv6EchoReply : ICMPv6 Echo Reply
# ICMPv6EchoRequest : ICMPv6 Echo Request
# ICMPv6HAADReply : ICMPv6 Home Agent Address Discovery Reply
# ICMPv6HAADRequest : ICMPv6 Home Agent Address Discovery Request
# ICMPv6MLDMultAddrRec : ICMPv6 MLDv2 - Multicast Address Record
# ICMPv6MLDone : MLD - Multicast Listener Done
# ICMPv6MLQuery : MLD - Multicast Listener Query
# ICMPv6MLQuery2 : MLDv2 - Multicast Listener Query
# ICMPv6MLReport : MLD - Multicast Listener Report
# ICMPv6MLReport2 : MLDv2 - Multicast Listener Report
# ICMPv6MPAdv : ICMPv6 Mobile Prefix Advertisement
# ICMPv6MPSol : ICMPv6 Mobile Prefix Solicitation
# ICMPv6MRD_Advertisement : ICMPv6 Multicast Router Discovery Advertisement
# ICMPv6MRD_Solicitation : ICMPv6 Multicast Router Discovery Solicitation
# ICMPv6MRD_Termination : ICMPv6 Multicast Router Discovery Termination
# ICMPv6NDOptAdvInterval : ICMPv6 Neighbor Discovery - Interval Advertisement
# ICMPv6NDOptDNSSL : ICMPv6 Neighbor Discovery Option - DNS Search List Option
# ICMPv6NDOptDstLLAddr : ICMPv6 Neighbor Discovery Option - Destination Link-Layer Address
# ICMPv6NDOptEFA : ICMPv6 Neighbor Discovery Option - Expanded Flags Option
# ICMPv6NDOptHAInfo : ICMPv6 Neighbor Discovery - Home Agent Information
# ICMPv6NDOptIPAddr : ICMPv6 Neighbor Discovery - IP Address Option (FH for MIPv6)
# ICMPv6NDOptLLA : ICMPv6 Neighbor Discovery - Link-Layer Address (LLA) Option (FH for MIPv6)
# ICMPv6NDOptMAP : ICMPv6 Neighbor Discovery - MAP Option
# ICMPv6NDOptMTU : ICMPv6 Neighbor Discovery Option - MTU
# ICMPv6NDOptNewRtrPrefix : ICMPv6 Neighbor Discovery - New Router Prefix Information Option (FH for MIPv6)
# ICMPv6NDOptPrefixInfo : ICMPv6 Neighbor Discovery Option - Prefix Information
# ICMPv6NDOptRDNSS : ICMPv6 Neighbor Discovery Option - Recursive DNS Server Option
# ICMPv6NDOptRedirectedHdr : ICMPv6 Neighbor Discovery Option - Redirected Header
# ICMPv6NDOptRouteInfo : ICMPv6 Neighbor Discovery Option - Route Information Option
# ICMPv6NDOptShortcutLimit : ICMPv6 Neighbor Discovery Option - NBMA Shortcut Limit
# ICMPv6NDOptSrcAddrList : ICMPv6 Inverse Neighbor Discovery Option - Source Address List
# ICMPv6NDOptSrcLLAddr : ICMPv6 Neighbor Discovery Option - Source Link-Layer Address
# ICMPv6NDOptTgtAddrList : ICMPv6 Inverse Neighbor Discovery Option - Target Address List
# ICMPv6NDOptUnknown : ICMPv6 Neighbor Discovery Option - Scapy Unimplemented
# ICMPv6ND_INDAdv : ICMPv6 Inverse Neighbor Discovery Advertisement
# ICMPv6ND_INDSol : ICMPv6 Inverse Neighbor Discovery Solicitation
# ICMPv6ND_NA : ICMPv6 Neighbor Discovery - Neighbor Advertisement
# ICMPv6ND_NS : ICMPv6 Neighbor Discovery - Neighbor Solicitation
# ICMPv6ND_RA : ICMPv6 Neighbor Discovery - Router Advertisement
# ICMPv6ND_RS : ICMPv6 Neighbor Discovery - Router Solicitation
# ICMPv6ND_Redirect : ICMPv6 Neighbor Discovery - Redirect
# ICMPv6NIQueryIPv4 : ICMPv6 Node Information Query - IPv4 Address Query
# ICMPv6NIQueryIPv6 : ICMPv6 Node Information Query - IPv6 Address Query
# ICMPv6NIQueryNOOP : ICMPv6 Node Information Query - NOOP Query
# ICMPv6NIQueryName : ICMPv6 Node Information Query - IPv6 Name Query
# ICMPv6NIReplyIPv4 : ICMPv6 Node Information Reply - IPv4 addresses
# ICMPv6NIReplyIPv6 : ICMPv6 Node Information Reply - IPv6 addresses
# ICMPv6NIReplyNOOP : ICMPv6 Node Information Reply - NOOP Reply
# ICMPv6NIReplyName : ICMPv6 Node Information Reply - Node Names
# ICMPv6NIReplyRefuse : ICMPv6 Node Information Reply - Responder refuses to supply answer
# ICMPv6NIReplyUnknown : ICMPv6 Node Information Reply - Qtype unknown to the responder
# ICMPv6PacketTooBig : ICMPv6 Packet Too Big
# ICMPv6ParamProblem : ICMPv6 Parameter Problem
# ICMPv6RPL  : RPL
# ICMPv6TimeExceeded : ICMPv6 Time Exceeded
# ICMPv6Unknown : Scapy6 ICMPv6 fallback class
# IP         : IP
# IPOption   : IP Option
# IPOption_Address_Extension : IP Option Address Extension
# IPOption_EOL : IP Option End of Options List
# IPOption_LSRR : IP Option Loose Source and Record Route
# IPOption_MTU_Probe : IP Option MTU Probe
# IPOption_MTU_Reply : IP Option MTU Reply
# IPOption_NOP : IP Option No Operation
# IPOption_RR : IP Option Record Route
# IPOption_Router_Alert : IP Option Router Alert
# IPOption_SDBM : IP Option Selective Directed Broadcast Mode
# IPOption_SSRR : IP Option Strict Source and Record Route
# IPOption_Security : IP Option Security
# IPOption_Stream_Id : IP Option Stream ID
# IPOption_Timestamp : IP Option Timestamp
# IPOption_Traceroute : IP Option Traceroute
# IPerror    : IP in ICMP
# IPerror6   : IPv6 in ICMPv6
# IPv46      : IP
# IPv6       : IPv6
# IPv6ExtHdrDestOpt : IPv6 Extension Header - Destination Options Header
# IPv6ExtHdrFragment : IPv6 Extension Header - Fragmentation header
# IPv6ExtHdrHopByHop : IPv6 Extension Header - Hop-by-Hop Options Header
# IPv6ExtHdrRouting : IPv6 Option Header Routing
# IPv6ExtHdrSegmentRouting : IPv6 Option Header Segment Routing
# IPv6ExtHdrSegmentRoutingTLV : IPv6 Option Header Segment Routing - Generic TLV
# IPv6ExtHdrSegmentRoutingTLVEgressNode : IPv6 Option Header Segment Routing - Egress Node TLV
# IPv6ExtHdrSegmentRoutingTLVHMAC : IPv6 Option Header Segment Routing - HMAC TLV
# IPv6ExtHdrSegmentRoutingTLVIngressNode : IPv6 Option Header Segment Routing - Ingress Node TLV
# IPv6ExtHdrSegmentRoutingTLVPad1 : IPv6 Option Header Segment Routing - Pad1 TLV
# IPv6ExtHdrSegmentRoutingTLVPadN : IPv6 Option Header Segment Routing - PadN TLV
# ISAKMP     : ISAKMP
# ISAKMP_class : None
# ISAKMP_payload : ISAKMP payload
# ISAKMP_payload_Hash : ISAKMP Hash
# ISAKMP_payload_ID : ISAKMP Identification
# ISAKMP_payload_KE : ISAKMP Key Exchange
# ISAKMP_payload_Nonce : ISAKMP Nonce
# ISAKMP_payload_Proposal : IKE proposal
# ISAKMP_payload_SA : ISAKMP SA
# ISAKMP_payload_Transform : IKE Transform
# ISAKMP_payload_VendorID : ISAKMP Vendor ID
# InheritOriginDNSStrPacket : None
# InlineQoSPacket : Inline QoS
# IrLAPCommand : IrDA Link Access Protocol Command
# IrLAPHead  : IrDA Link Access Protocol Header
# IrLMP      : IrDA Link Management Protocol
# Jumbo      : Jumbo Payload
# KERB_VALIDATION_INFO : None
# KERB_VALIDATION_INFO_WRAP : None
# KRB5_GSS   : None
# KRB5_GSS_Delete_sec_context_RFC1964 : Kerberos v5 GSS_Delete_sec_context (RFC1964)
# KRB5_GSS_GetMIC : Kerberos v5 GSS_GetMIC
# KRB5_GSS_GetMIC_RFC1964 : Kerberos v5 GSS_GetMIC (RFC1964)
# KRB5_GSS_Wrap : Kerberos v5 GSS_Wrap
# KRB5_GSS_Wrap_RFC1964 : Kerberos v5 GSS_Wrap (RFC1964)
# KRB5_InitialContextToken_innerContextToken : Kerberos v5 InitialContextToken innerContextToken (RFC1964)
# KRB_AP_REP : None
# KRB_AP_REQ : None
# KRB_AS_REP : None
# KRB_AS_REQ : None
# KRB_Authenticator : None
# KRB_ERROR  : None
# KRB_InitialContextToken : Kerberos v5 InitialContextToken (RFC1964)
# KRB_KDC_REQ_BODY : None
# KRB_TGS_REP : None
# KRB_TGS_REQ : None
# KRB_Ticket : None
# Kerberos   : None
# KerberosTCPHeader : None
# KrbFastArmor : None
# KrbFastArmoredRep : None
# KrbFastArmoredReq : None
# KrbFastFinished : None
# KrbFastReq : None
# KrbFastResponse : None
# L2CAP_CmdHdr : L2CAP command header
# L2CAP_CmdRej : L2CAP Command Rej
# L2CAP_ConfReq : L2CAP Conf Req
# L2CAP_ConfResp : L2CAP Conf Resp
# L2CAP_ConnReq : L2CAP Conn Req
# L2CAP_ConnResp : L2CAP Conn Resp
# L2CAP_Connection_Parameter_Update_Request : L2CAP Connection Parameter Update Request
# L2CAP_Connection_Parameter_Update_Response : L2CAP Connection Parameter Update Response
# L2CAP_DisconnReq : L2CAP Disconn Req
# L2CAP_DisconnResp : L2CAP Disconn Resp
# L2CAP_Hdr  : L2CAP header
# L2CAP_InfoReq : L2CAP Info Req
# L2CAP_InfoResp : L2CAP Info Resp
# L2TP       : L2TP
# LDAP       : None
# LDAPReferral : None
# LDAP_AbandonRequest : None
# LDAP_BindRequest : None
# LDAP_BindResponse : None
# LDAP_Control : None
# LDAP_Filter : None
# LDAP_FilterAnd : None
# LDAP_FilterOr : None
# LDAP_FilterPresent : None
# LDAP_SaslCredentials : None
# LDAP_SearchRequest : None
# LDAP_SearchRequestAttribute : None
# LDAP_SearchResponseEntry : None
# LDAP_SearchResponseEntryAttribute : None
# LDAP_SearchResponseEntryAttributeValue : None
# LDAP_SearchResponseResultCode : None
# LDAP_SubstringFilter : None
# LDAP_SubstringFilterAny : None
# LDAP_SubstringFilterFinal : None
# LDAP_SubstringFilterInitial : None
# LDAP_SubstringFilterStr : None
# LDAP_UnbindRequest : None
# LEAP       : Cisco LEAP
# LLC        : LLC
# LLMNRQuery : Link Local Multicast Node Resolution - Query
# LLMNRResponse : Link Local Multicast Node Resolution - Response
# LLTD       : LLTD
# LLTDAttribute : LLTD Attribute
# LLTDAttribute80211MaxRate : LLTD Attribute - 802.11 Max Rate
# LLTDAttribute80211PhysicalMedium : LLTD Attribute - 802.11 Physical Medium
# LLTDAttributeCharacteristics : LLTD Attribute - Characteristics
# LLTDAttributeDeviceUUID : LLTD Attribute - Device UUID
# LLTDAttributeEOP : LLTD Attribute - End Of Property
# LLTDAttributeHostID : LLTD Attribute - Host ID
# LLTDAttributeIPv4Address : LLTD Attribute - IPv4 Address
# LLTDAttributeIPv6Address : LLTD Attribute - IPv6 Address
# LLTDAttributeLargeTLV : LLTD Attribute - Large TLV
# LLTDAttributeLinkSpeed : LLTD Attribute - Link Speed
# LLTDAttributeMachineName : LLTD Attribute - Machine Name
# LLTDAttributePerformanceCounterFrequency : LLTD Attribute - Performance Counter Frequency
# LLTDAttributePhysicalMedium : LLTD Attribute - Physical Medium
# LLTDAttributeQOSCharacteristics : LLTD Attribute - QoS Characteristics
# LLTDAttributeSeesList : LLTD Attribute - Sees List Working Set
# LLTDDiscover : LLTD - Discover
# LLTDEmit   : LLTD - Emit
# LLTDEmiteeDesc : LLTD - Emitee Desc
# LLTDHello  : LLTD - Hello
# LLTDQueryLargeTlv : LLTD - Query Large Tlv
# LLTDQueryLargeTlvResp : LLTD - Query Large Tlv Response
# LLTDQueryResp : LLTD - Query Response
# LLTDRecveeDesc : LLTD - Recvee Desc
# LL_CHANNEL_MAP_IND : LL_CHANNEL_MAP_IND
# LL_CONNECTION_PARAM_REQ : LL_CONNECTION_PARAM_REQ
# LL_CONNECTION_PARAM_RSP : LL_CONNECTION_PARAM_RSP
# LL_CONNECTION_UPDATE_IND : LL_CONNECTION_UPDATE_IND
# LL_ENC_REQ : LL_ENC_REQ
# LL_ENC_RSP : LL_ENC_RSP
# LL_FEATURE_REQ : LL_FEATURE_REQ
# LL_FEATURE_RSP : LL_FEATURE_RSP
# LL_LENGTH_REQ :  LL_LENGTH_REQ
# LL_LENGTH_RSP :  LL_LENGTH_RSP
# LL_MIN_USED_CHANNELS_IND : LL_MIN_USED_CHANNELS_IND
# LL_PAUSE_ENC_REQ : LL_PAUSE_ENC_REQ
# LL_PAUSE_ENC_RSP : LL_PAUSE_ENC_RSP
# LL_PHY_REQ : LL_PHY_REQ
# LL_PHY_RSP : LL_PHY_RSP
# LL_PHY_UPDATE_IND : LL_PHY_UPDATE_IND
# LL_PING_REQ : LL_PING_REQ
# LL_PING_RSP : LL_PING_RSP
# LL_REJECT_EXT_IND : LL_REJECT_EXT_IND
# LL_REJECT_IND : LL_REJECT_IND
# LL_SLAVE_FEATURE_REQ : LL_SLAVE_FEATURE_REQ
# LL_START_ENC_REQ : LL_START_ENC_REQ
# LL_START_ENC_RSP : LL_START_ENC_RSP
# LL_TERMINATE_IND : LL_TERMINATE_IND
# LL_UNKNOWN_RSP : LL_UNKNOWN_RSP
# LL_VERSION_IND : LL_VERSION_IND
# LM_RESPONSE : None
# LMv2_RESPONSE : None
# LastReqItem : None
# LeaseDurationPacket : Lease Duration
# LinkStatusEntry : ZigBee Link Status Entry
# LoWPANBroadcast : 6LoWPAN Broadcast
# LoWPANFragmentationFirst : 6LoWPAN First Fragmentation Packet
# LoWPANFragmentationSubsequent : 6LoWPAN Subsequent Fragmentation Packet
# LoWPANMesh : 6LoWPAN Mesh Packet
# LoWPANUncompressedIPv6 : 6LoWPAN Uncompressed IPv6
# LoWPAN_HC1 : LoWPAN_HC1 Compressed IPv6
# LoWPAN_HC2_UDP : 6LoWPAN HC1 UDP encoding
# LoWPAN_IPHC : LoWPAN IP Header Compression Packet
# LoWPAN_NHC : LOWPAN_NHC
# LoWPAN_NHC_Hdr : None
# LoWPAN_NHC_IPv6Ext : None
# LoWPAN_NHC_UDP : None
# LocatorPacket : RTPS Locator
# Loopback   : Loopback
# MACsecSCI  : SCI
# MGCP       : MGCP
# MIP6MH_BA  : IPv6 Mobility Header - Binding ACK
# MIP6MH_BE  : IPv6 Mobility Header - Binding Error
# MIP6MH_BRR : IPv6 Mobility Header - Binding Refresh Request
# MIP6MH_BU  : IPv6 Mobility Header - Binding Update
# MIP6MH_CoT : IPv6 Mobility Header - Care-of Test
# MIP6MH_CoTI : IPv6 Mobility Header - Care-of Test Init
# MIP6MH_Generic : IPv6 Mobility Header - Generic Message
# MIP6MH_HoT : IPv6 Mobility Header - Home Test
# MIP6MH_HoTI : IPv6 Mobility Header - Home Test Init
# MIP6OptAltCoA : MIPv6 Option - Alternate Care-of Address
# MIP6OptBRAdvice : Mobile IPv6 Option - Binding Refresh Advice
# MIP6OptBindingAuthData : MIPv6 Option - Binding Authorization Data
# MIP6OptCGAParams : MIPv6 option - CGA Parameters
# MIP6OptCGAParamsReq : MIPv6 option - CGA Parameters Request
# MIP6OptCareOfTest : MIPv6 option - Care-of Test
# MIP6OptCareOfTestInit : MIPv6 option - Care-of Test Init
# MIP6OptHomeKeygenToken : MIPv6 option - Home Keygen Token
# MIP6OptLLAddr : MIPv6 Option - Link-Layer Address (MH-LLA)
# MIP6OptMNID : MIPv6 Option - Mobile Node Identifier
# MIP6OptMobNetPrefix : NEMO Option - Mobile Network Prefix
# MIP6OptMsgAuth : MIPv6 Option - Mobility Message Authentication
# MIP6OptNonceIndices : MIPv6 Option - Nonce Indices
# MIP6OptReplayProtection : MIPv6 option - Replay Protection
# MIP6OptSignature : MIPv6 option - Signature
# MIP6OptUnknown : Scapy6 - Unknown Mobility Option
# MKABasicParamSet : Basic Parameter Set
# MKADistributedCAKParamSet : Distributed CAK parameter set
# MKADistributedSAKParamSet : Distributed SAK parameter set
# MKAICVSet  : ICV
# MKALivePeerListParamSet : Live Peer List Parameter Set
# MKAPDU     : MKPDU
# MKAParamSet : None
# MKAPeerListTuple : Peer List Tuple
# MKAPotentialPeerListParamSet : Potential Peer List Parameter Set
# MKASAKUseParamSet : SAK Use Parameter Set
# MPacketPreamble : MPacket Preamble
# MethodData : None
# MobileIP   : Mobile IP (RFC3344)
# MobileIPRRP : Mobile IP Registration Reply (RFC3344)
# MobileIPRRQ : Mobile IP Registration Request (RFC3344)
# MobileIPTunnelData : Mobile IP Tunnel Data Message (RFC3519)
# NBNSHeader : NBNS Header
# NBNSNodeStatusRequest : NBNS status request
# NBNSNodeStatusResponse : NBNS Node Status Response
# NBNSNodeStatusResponseService : NBNS Node Status Response Service
# NBNSQueryRequest : NBNS query request
# NBNSQueryResponse : NBNS query response
# NBNSRegistrationRequest : NBNS registration request
# NBNSWackResponse : NBNS Wait for Acknowledgement Response
# NBNS_ADD_ENTRY : None
# NBTDatagram : NBT Datagram Packet
# NBTSession : NBT Session Packet
# NDRConformantArray : None
# NDRConformantString : None
# NDRContextHandle : None
# NDRPacket  : None
# NDRPacket  : None
# NDRPointer : None
# NDRSerialization1Header : None
# NDRSerialization1PrivateHeader : None
# NDRUnion   : None
# NDRVaryingArray : None
# NEGOEX_BYTE_VECTOR : None
# NEGOEX_CHECKSUM : None
# NEGOEX_EXCHANGE_MESSAGE : None
# NEGOEX_EXCHANGE_NTLM : None
# NEGOEX_EXCHANGE_NTLM_ITEM : None
# NEGOEX_EXTENSION_VECTOR : None
# NEGOEX_MESSAGE_HEADER : None
# NEGOEX_NEGO_MESSAGE : None
# NEGOEX_VERIFY_MESSAGE : None
# NL_AUTH_MESSAGE : NL_AUTH_MESSAGE
# NL_AUTH_SIGNATURE : NL_AUTH_(SHA2_)SIGNATURE
# NTLMSSP_MESSAGE_SIGNATURE : None
# NTLM_AUTHENTICATE : NTLM Authenticate
# NTLM_AUTHENTICATE_V2 : NTLM Authenticate
# NTLM_CHALLENGE : NTLM Challenge
# NTLM_Header : NTLM Header
# NTLM_NEGOTIATE : NTLM Negotiate
# NTLM_RESPONSE : None
# NTLMv2_CLIENT_CHALLENGE : None
# NTLMv2_RESPONSE : None
# NTP        : None
# NTPAuthenticator : Authenticator
# NTPClockStatusPacket : clock status
# NTPConfPeer : conf_peer
# NTPConfRestrict : conf_restrict
# NTPConfTrap : conf_trap
# NTPConfUnpeer : conf_unpeer
# NTPControl : Control message
# NTPErrorStatusPacket : error status
# NTPExtension : extension
# NTPExtensions : NTPv4 extensions
# NTPHeader  : NTPHeader
# NTPInfoAuth : info_auth
# NTPInfoControl : info_control
# NTPInfoIOStats : info_io_stats
# NTPInfoIfStatsIPv4 : info_if_stats
# NTPInfoIfStatsIPv6 : info_if_stats
# NTPInfoKernel : info_kernel
# NTPInfoLoop : info_loop
# NTPInfoMemStats : info_mem_stats
# NTPInfoMonitor1 : InfoMonitor1
# NTPInfoPeer : info_peer
# NTPInfoPeerList : info_peer_list
# NTPInfoPeerStats : info_peer_stats
# NTPInfoPeerSummary : info_peer_summary
# NTPInfoSys : info_sys
# NTPInfoSysStats : info_sys_stats
# NTPInfoTimerStats : info_timer_stats
# NTPPeerStatusDataPacket : data / peer status
# NTPPeerStatusPacket : peer status
# NTPPrivate : Private (mode 7)
# NTPPrivatePktTail : req_pkt_tail
# NTPPrivateReqPacket : request data
# NTPStatusPacket : status
# NTPSystemStatusPacket : system status
# NetBIOS_DS : NetBIOS datagram service
# NetflowDataflowsetV9 : Netflow DataFlowSet V9/10
# NetflowFlowsetV9 : Netflow FlowSet V9/10
# NetflowHeader : Netflow Header
# NetflowHeaderV1 : Netflow Header v1
# NetflowHeaderV10 : IPFix (Netflow V10) Header
# NetflowHeaderV5 : Netflow Header v5
# NetflowHeaderV9 : Netflow Header V9
# NetflowOptionsFlowset10 : Netflow V10 (IPFix) Options Template FlowSet
# NetflowOptionsFlowsetOptionV9 : Netflow Options Template FlowSet V9/10 - Option
# NetflowOptionsFlowsetScopeV9 : Netflow Options Template FlowSet V9/10 - Scope
# NetflowOptionsFlowsetV9 : Netflow Options Template FlowSet V9
# NetflowOptionsRecordOptionV9 : Netflow Options Template Record V9/10 - Option
# NetflowOptionsRecordScopeV9 : Netflow Options Template Record V9/10 - Scope
# NetflowRecordV1 : Netflow Record v1
# NetflowRecordV5 : Netflow Record v5
# NetflowRecordV9 : Netflow DataFlowset Record V9/10
# NetflowTemplateFieldV9 : Netflow Flowset Template Field V9/10
# NetflowTemplateV9 : Netflow Flowset Template V9/10
# NoPayload  : None
# OCSP_ByKey : None
# OCSP_ByName : None
# OCSP_CertID : None
# OCSP_CertStatus : None
# OCSP_GoodInfo : None
# OCSP_ResponderID : None
# OCSP_Response : None
# OCSP_ResponseBytes : None
# OCSP_ResponseData : None
# OCSP_RevokedInfo : None
# OCSP_SingleResponse : None
# OCSP_UnknownInfo : None
# PACTYPE    : PACTYPE - PAC
# PAC_ATTRIBUTES_INFO : None
# PAC_CLIENT_CLAIMS_INFO : None
# PAC_CLIENT_INFO : None
# PAC_CREDENTIAL_INFO : None
# PAC_DEVICE_INFO : None
# PAC_DEVICE_INFO_WRAP : None
# PAC_INFO_BUFFER : None
# PAC_REQUESTOR : None
# PAC_SIGNATURE_DATA : None
# PADATA     : None
# PA_AUTHENTICATION_SET : None
# PA_AUTHENTICATION_SET_ELEM : None
# PA_ENC_TS_ENC : None
# PA_FX_FAST_REPLY : None
# PA_FX_FAST_REQUEST : None
# PA_PAC_OPTIONS : None
# PA_PAC_REQUEST : None
# PA_PK_AS_REP : None
# PA_PK_AS_REQ : None
# PA_SUPPORTED_ENCTYPES : None
# PDOMAIN_GROUP_MEMBERSHIP : None
# PGROUP_MEMBERSHIP : None
# PIDPacketBase : PID Base Packet
# PID_BUILTIN_ENDPOINT_QOS : PID_BUILTIN_ENDPOINT_QOS
# PID_BUILTIN_ENDPOINT_SET : PID_BUILTIN_ENDPOINT_SET
# PID_CONTENT_FILTER_PROPERTY : PID_CONTENT_FILTER_PROPERTY
# PID_DEADLINE : PID_DEADLINE
# PID_DEFAULT_MULTICAST_LOCATOR : PID_DEFAULT_MULTICAST_LOCATOR
# PID_DEFAULT_UNICAST_IPADDRESS : PID_DEFAULT_UNICAST_IPADDRESS
# PID_DEFAULT_UNICAST_LOCATOR : PID_DEFAULT_UNICAST_LOCATOR
# PID_DEFAULT_UNICAST_PORT : PID_DEFAULT_UNICAST_PORT
# PID_DESTINATION_ORDER : PID_DESTINATION_ORDER
# PID_DOMAIN_ID : PID_DOMAIN_ID
# PID_DOMAIN_TAG : PID_DOMAIN_TAG
# PID_DURABILITY : PID_DURABILITY
# PID_DURABILITY_SERVICE : PID_DURABILITY_SERVICE
# PID_ENDPOINT_GUID : PID_ENDPOINT_GUID
# PID_ENTITY_NAME : PID_ENTITY_NAME
# PID_EXPECTS_INLINE_QOS : PID_EXPECTS_INLINE_QOS
# PID_GROUP_DATA : PID_GROUP_DATA
# PID_GROUP_ENTITYID : PID_GROUP_ENTITYID
# PID_GROUP_GUID : PID_GROUP_GUID
# PID_HISTORY : PID_HISTORY
# PID_KEY_HASH : PID_KEY_HASH
# PID_LATENCY_BUDGET : PID_LATENCY_BUDGET
# PID_LIFESPAN : PID_LIFESPAN
# PID_LIVELINESS : PID_LIVELINESS
# PID_METATRAFFIC_MULTICAST_IPADDRESS : PID_METATRAFFIC_MULTICAST_IPADDRESS
# PID_METATRAFFIC_MULTICAST_LOCATOR : PID_METATRAFFIC_MULTICAST_LOCATOR
# PID_METATRAFFIC_MULTICAST_PORT : PID_METATRAFFIC_MULTICAST_PORT
# PID_METATRAFFIC_UNICAST_IPADDRESS : PID_METATRAFFIC_UNICAST_IPADDRESS
# PID_METATRAFFIC_UNICAST_LOCATOR : PID_METATRAFFIC_UNICAST_LOCATOR
# PID_METATRAFFIC_UNICAST_PORT : PID_METATRAFFIC_UNICAST_PORT
# PID_MULTICAST_IPADDRESS : PID_MULTICAST_IPADDRESS
# PID_MULTICAST_LOCATOR : PID_MULTICAST_LOCATOR
# PID_OWNERSHIP : PID_OWNERSHIP
# PID_OWNERSHIP_STRENGTH : PID_OWNERSHIP_STRENGTH
# PID_PAD    : PID_PAD
# PID_PARTICIPANT_BUILTIN_ENDPOINTS : PID_PARTICIPANT_BUILTIN_ENDPOINTS
# PID_PARTICIPANT_GUID : PID_PARTICIPANT_GUID
# PID_PARTICIPANT_LEASE_DURATION : PID_PARTICIPANT_LEASE_DURATION
# PID_PARTICIPANT_MANUAL_LIVELINESS_COUNT : PID_PARTICIPANT_MANUAL_LIVELINESS_COUNT
# PID_PARTITION : PID_PARTITION
# PID_PLUGIN_PROMISCUITY_KIND : PID_PLUGIN_PROMISCUITY_KIND
# PID_PRESENTATION : PID_PRESENTATION
# PID_PRODUCT_VERSION : PID_PRODUCT_VERSION
# PID_PROPERTY_LIST : PID_PROPERTY_LIST
# PID_PROTOCOL_VERSION : PID_PROTOCOL_VERSION
# PID_REACHABILITY_LEASE_DURATION : PID_REACHABILITY_LEASE_DURATION
# PID_RELIABILITY : PID_RELIABILITY
# PID_RESOURCE_LIMITS : PID_RESOURCE_LIMITS
# PID_RTI_DOMAIN_ID : PID_RTI_DOMAIN_ID
# PID_SENTINEL : PID_SENTINEL
# PID_STATUS_INFO : PID_STATUS_INFO
# PID_TIME_BASED_FILTER : PID_TIME_BASED_FILTER
# PID_TOPIC_DATA : PID_TOPIC_DATA
# PID_TOPIC_NAME : PID_TOPIC_NAME
# PID_TRANSPORT_INFO_LIST : PID_TRANSPORT_INFO_LIST
# PID_TRANSPORT_PRIO : PID_TRANSPORT_PRIO
# PID_TRANSPORT_PRIORITY : PID_TRANSPORT_PRIORITY
# PID_TYPE_MAX_SIZE_SERIALIZED : PID_TYPE_MAX_SIZE_SERIALIZED
# PID_TYPE_NAME : PID_TYPE_NAME
# PID_UNICAST_LOCATOR : PID_UNICAST_LOCATOR
# PID_UNKNOWN : PID_UNKNOWN
# PID_USER_DATA : PID_USER_DATA
# PID_VENDOR_BUILTIN_ENDPOINT_SET : PID_VENDOR_BUILTIN_ENDPOINT_SET
# PID_VENDOR_ID : PID_VENDOR_ID
# PKERB_SID_AND_ATTRIBUTES : None
# PMKIDListPacket : PMKIDs
# PPI        : Per-Packet Information header (PPI)
# PPI_Element : PPI Element
# PPI_Hdr    : PPI Header
# PPP        : PPP Link Layer
# PPP_CHAP   : PPP Challenge Handshake Authentication Protocol
# PPP_CHAP_ChallengeResponse : PPP Challenge Handshake Authentication Protocol
# PPP_ECP    : None
# PPP_ECP_Option : PPP ECP Option
# PPP_ECP_Option_OUI : PPP ECP Option
# PPP_IPCP   : None
# PPP_IPCP_Option : PPP IPCP Option
# PPP_IPCP_Option_DNS1 : PPP IPCP Option: DNS1 Address
# PPP_IPCP_Option_DNS2 : PPP IPCP Option: DNS2 Address
# PPP_IPCP_Option_IPAddress : PPP IPCP Option: IP Address
# PPP_IPCP_Option_NBNS1 : PPP IPCP Option: NBNS1 Address
# PPP_IPCP_Option_NBNS2 : PPP IPCP Option: NBNS2 Address
# PPP_LCP    : PPP Link Control Protocol
# PPP_LCP_ACCM_Option : PPP LCP Option
# PPP_LCP_Auth_Protocol_Option : PPP LCP Option
# PPP_LCP_Callback_Option : PPP LCP Option
# PPP_LCP_Code_Reject : PPP Link Control Protocol
# PPP_LCP_Configure : PPP Link Control Protocol
# PPP_LCP_Discard_Request : PPP Link Control Protocol
# PPP_LCP_Echo : PPP Link Control Protocol
# PPP_LCP_MRU_Option : PPP LCP Option
# PPP_LCP_Magic_Number_Option : PPP LCP Option
# PPP_LCP_Option : PPP LCP Option
# PPP_LCP_Protocol_Reject : PPP Link Control Protocol
# PPP_LCP_Quality_Protocol_Option : PPP LCP Option
# PPP_LCP_Terminate : PPP Link Control Protocol
# PPP_PAP    : PPP Password Authentication Protocol
# PPP_PAP_Request : PPP Password Authentication Protocol
# PPP_PAP_Response : PPP Password Authentication Protocol
# PPPoE      : PPP over Ethernet
# PPPoED     : PPP over Ethernet Discovery
# PPPoED_Tags : PPPoE Tag List
# PPPoETag   : PPPoE Tag
# PPTP       : PPTP
# PPTPCallClearRequest : PPTP Call Clear Request
# PPTPCallDisconnectNotify : PPTP Call Disconnect Notify
# PPTPEchoReply : PPTP Echo Reply
# PPTPEchoRequest : PPTP Echo Request
# PPTPIncomingCallConnected : PPTP Incoming Call Connected
# PPTPIncomingCallReply : PPTP Incoming Call Reply
# PPTPIncomingCallRequest : PPTP Incoming Call Request
# PPTPOutgoingCallReply : PPTP Outgoing Call Reply
# PPTPOutgoingCallRequest : PPTP Outgoing Call Request
# PPTPSetLinkInfo : PPTP Set Link Info
# PPTPStartControlConnectionReply : PPTP Start Control Connection Reply
# PPTPStartControlConnectionRequest : PPTP Start Control Connection Request
# PPTPStopControlConnectionReply : PPTP Stop Control Connection Reply
# PPTPStopControlConnectionRequest : PPTP Stop Control Connection Request
# PPTPWANErrorNotify : PPTP WAN Error Notify
# PSID       : None
# Packet     : None
# Pad1       : Pad1
# PadN       : PadN
# Padding    : Padding
# ParameterListPacket : PID list
# ParticipantMessageDataPacket : Participant Message Data
# PrincipalName : None
# PrismHeader : Prism header
# ProductVersionPacket : Product Version
# ProtocolVersionPacket : RTPS Protocol Version
# PseudoIPv6 : Pseudo IPv6 Header
# RIP        : RIP header
# RIPAuth    : RIP authentication
# RIPEntry   : RIP entry
# RPC_SID_IDENTIFIER_AUTHORITY : None
# RPC_UNICODE_STRING : None
# RSAOtherPrimeInfo : None
# RSAPrivateKey : None
# RSAPrivateKey_OpenSSL : None
# RSAPublicKey : None
# RSNCipherSuite : Cipher suite
# RTP        : RTP
# RTPExtension : RTP extension
# RTPS       : RTPS Header
# RTPSMessage : RTPS Message
# RTPSSubMessage_ACKNACK : RTPS ACKNACK (0x06)
# RTPSSubMessage_DATA : RTPS DATA (0x15)
# RTPSSubMessage_DATA_FRAG : RTPS DATA_FRAG (0x16)
# RTPSSubMessage_GAP : RTPS GAP (0x08)
# RTPSSubMessage_HEARTBEAT : RTPS HEARTBEAT (0x07)
# RTPSSubMessage_INFO_DST : RTPS INFO_DTS (0x0e)
# RTPSSubMessage_INFO_TS : RTPS INFO_TS (0x09)
# RTPSSubMessage_PAD : RTPS PAD (0x01)
# RTPSSubMessage_SEC_BODY : RTPS SEC_BODY (0x30)
# RTPSSubMessage_SEC_POSTFIX : RTPS SEC_POSTFIX (0x32)
# RTPSSubMessage_SEC_PREFIX : RTPS SEC_PREFIX (0x31)
# RTPSSubMessage_SRTPS_POSTFIX : RTPS SRPTS_POSTFIX (0x34)
# RTPSSubMessage_SRTPS_PREFIX : RTPS SRPTS_PREFIX (0x33)
# RadioTap   : RadioTap
# RadioTapExtendedPresenceMask : RadioTap Extended presence mask
# RadioTapTLV : None
# Radius     : RADIUS
# RadiusAttr_ARAP_Security : Radius Attribute
# RadiusAttr_Acct_Authentic : Radius Attribute
# RadiusAttr_Acct_Delay_Time : Radius Attribute
# RadiusAttr_Acct_Input_Gigawords : Radius Attribute
# RadiusAttr_Acct_Input_Octets : Radius Attribute
# RadiusAttr_Acct_Input_Packets : Radius Attribute
# RadiusAttr_Acct_Interim_Interval : Radius Attribute
# RadiusAttr_Acct_Link_Count : Radius Attribute
# RadiusAttr_Acct_Output_Gigawords : Radius Attribute
# RadiusAttr_Acct_Output_Octets : Radius Attribute
# RadiusAttr_Acct_Output_Packets : Radius Attribute
# RadiusAttr_Acct_Session_Time : Radius Attribute
# RadiusAttr_Acct_Status_Type : Radius Attribute
# RadiusAttr_Acct_Terminate_Cause : Radius Attribute
# RadiusAttr_Acct_Tunnel_Packets_Lost : Radius Attribute
# RadiusAttr_EAP_Message : EAP-Message
# RadiusAttr_Egress_VLANID : Radius Attribute
# RadiusAttr_Framed_AppleTalk_Link : Radius Attribute
# RadiusAttr_Framed_AppleTalk_Network : Radius Attribute
# RadiusAttr_Framed_IPX_Network : Radius Attribute
# RadiusAttr_Framed_IP_Address : Radius Attribute
# RadiusAttr_Framed_IP_Netmask : Radius Attribute
# RadiusAttr_Framed_MTU : Radius Attribute
# RadiusAttr_Framed_Protocol : Radius Attribute
# RadiusAttr_Idle_Timeout : Radius Attribute
# RadiusAttr_Login_IP_Host : Radius Attribute
# RadiusAttr_Login_TCP_Port : Radius Attribute
# RadiusAttr_Management_Privilege_Level : Radius Attribute
# RadiusAttr_Message_Authenticator : Radius Attribute
# RadiusAttr_Mobility_Domain_Id : Radius Attribute
# RadiusAttr_NAS_IP_Address : Radius Attribute
# RadiusAttr_NAS_Port : Radius Attribute
# RadiusAttr_NAS_Port_Type : Radius Attribute
# RadiusAttr_PMIP6_Home_DHCP4_Server_Address : Radius Attribute
# RadiusAttr_PMIP6_Home_IPv4_Gateway : Radius Attribute
# RadiusAttr_PMIP6_Home_LMA_IPv4_Address : Radius Attribute
# RadiusAttr_PMIP6_Visited_DHCP4_Server_Address : Radius Attribute
# RadiusAttr_PMIP6_Visited_IPv4_Gateway : Radius Attribute
# RadiusAttr_PMIP6_Visited_LMA_IPv4_Address : Radius Attribute
# RadiusAttr_Password_Retry : Radius Attribute
# RadiusAttr_Port_Limit : Radius Attribute
# RadiusAttr_Preauth_Timeout : Radius Attribute
# RadiusAttr_Service_Type : Radius Attribute
# RadiusAttr_Session_Timeout : Radius Attribute
# RadiusAttr_State : Radius Attribute
# RadiusAttr_Tunnel_Preference : Radius Attribute
# RadiusAttr_User_Name : Radius Attribute
# RadiusAttr_User_Password : Radius Attribute
# RadiusAttr_Vendor_Specific : Vendor-Specific
# RadiusAttr_WLAN_AKM_Suite : Radius Attribute
# RadiusAttr_WLAN_Group_Cipher : Radius Attribute
# RadiusAttr_WLAN_Group_Mgmt_Cipher : Radius Attribute
# RadiusAttr_WLAN_Pairwise_Cipher : Radius Attribute
# RadiusAttr_WLAN_RF_Band : Radius Attribute
# RadiusAttr_WLAN_Reason_Code : Radius Attribute
# RadiusAttr_WLAN_Venue_Info : Radius Attribute
# RadiusAttribute : Radius Attribute
# Raw        : Raw
# RouterAlert : Router Alert
# SCTP       : None
# SCTPChunkAbort : None
# SCTPChunkAddressConf : None
# SCTPChunkAddressConfAck : None
# SCTPChunkAuthentication : None
# SCTPChunkCookieAck : None
# SCTPChunkCookieEcho : None
# SCTPChunkData : None
# SCTPChunkError : None
# SCTPChunkHeartbeatAck : None
# SCTPChunkHeartbeatReq : None
# SCTPChunkInit : None
# SCTPChunkInitAck : None
# SCTPChunkParamAdaptationLayer : None
# SCTPChunkParamAddIPAddr : None
# SCTPChunkParamChunkList : None
# SCTPChunkParamCookiePreservative : None
# SCTPChunkParamDelIPAddr : None
# SCTPChunkParamECNCapable : None
# SCTPChunkParamErrorIndication : None
# SCTPChunkParamFwdTSN : None
# SCTPChunkParamHeartbeatInfo : None
# SCTPChunkParamHostname : None
# SCTPChunkParamIPv4Addr : None
# SCTPChunkParamIPv6Addr : None
# SCTPChunkParamRandom : None
# SCTPChunkParamRequestedHMACFunctions : None
# SCTPChunkParamSetPrimaryAddr : None
# SCTPChunkParamStateCookie : None
# SCTPChunkParamSuccessIndication : None
# SCTPChunkParamSupportedAddrTypes : None
# SCTPChunkParamSupportedExtensions : None
# SCTPChunkParamUnrocognizedParam : None
# SCTPChunkSACK : None
# SCTPChunkShutdown : None
# SCTPChunkShutdownAck : None
# SCTPChunkShutdownComplete : None
# SCTPerror  : SCTP in ICMP
# SECURITY_DESCRIPTOR : None
# SMB2_CREATE_ALLOCATION_SIZE : None
# SMB2_CREATE_APP_INSTANCE_ID : None
# SMB2_CREATE_APP_INSTANCE_VERSION : None
# SMB2_CREATE_DURABLE_HANDLE_RECONNECT : None
# SMB2_CREATE_DURABLE_HANDLE_RECONNECT_V2 : None
# SMB2_CREATE_DURABLE_HANDLE_REQUEST : None
# SMB2_CREATE_DURABLE_HANDLE_REQUEST_V2 : None
# SMB2_CREATE_DURABLE_HANDLE_RESPONSE : None
# SMB2_CREATE_DURABLE_HANDLE_RESPONSE_V2 : None
# SMB2_CREATE_QUERY_MAXIMAL_ACCESS_REQUEST : None
# SMB2_CREATE_QUERY_MAXIMAL_ACCESS_RESPONSE : None
# SMB2_CREATE_QUERY_ON_DISK_ID : None
# SMB2_CREATE_REQUEST_LEASE : None
# SMB2_CREATE_REQUEST_LEASE_V2 : None
# SMB2_CREATE_RESPONSE_LEASE : None
# SMB2_CREATE_RESPONSE_LEASE_V2 : None
# SMB2_CREATE_TIMEWARP_TOKEN : None
# SMB2_Cancel_Request : SMB2 CANCEL Request
# SMB2_Change_Notify_Request : SMB2 CHANGE NOTIFY Request
# SMB2_Change_Notify_Response : SMB2 CHANGE NOTIFY Response
# SMB2_Close_Request : SMB2 CLOSE Request
# SMB2_Close_Response : SMB2 CLOSE Response
# SMB2_Compression_Capabilities : SMB2 Compression Capabilities
# SMB2_Compression_Transform_Header : SMB2 Compression Transform Header
# SMB2_Create_Context : SMB2 CREATE CONTEXT
# SMB2_Create_Request : SMB2 CREATE Request
# SMB2_Create_Response : SMB2 CREATE Response
# SMB2_Encryption_Capabilities : SMB2 Encryption Capabilities
# SMB2_Error_Response : SMB2 Error Response
# SMB2_FILEID : None
# SMB2_Header : SMB2 Header
# SMB2_IOCTL_Request : SMB2 IOCTL Request
# SMB2_IOCTL_Response : SMB2 IOCTL Response
# SMB2_IOCTL_Validate_Negotiate_Info_Request : SMB2 IOCTL Validate Negotiate Info
# SMB2_IOCTL_Validate_Negotiate_Info_Response : SMB2 IOCTL Validate Negotiate Info
# SMB2_Negotiate_Context : SMB2 Negotiate Context
# SMB2_Negotiate_Protocol_Request : SMB2 Negotiate Protocol Request
# SMB2_Negotiate_Protocol_Response : SMB2 Negotiate Protocol Response
# SMB2_Netname_Negotiate_Context_ID : SMB2 Netname Negotiate Context ID
# SMB2_Preauth_Integrity_Capabilities : SMB2 Preauth Integrity Capabilities
# SMB2_Query_Directory_Request : SMB2 QUERY DIRECTORY Request
# SMB2_Query_Directory_Response : SMB2 QUERY DIRECTORY Response
# SMB2_Query_Info_Request : SMB2 QUERY INFO Request
# SMB2_Query_Info_Response : SMB2 QUERY INFO Response
# SMB2_Query_Quota_Info : None
# SMB2_Read_Request : SMB2 READ Request
# SMB2_Read_Response : SMB2 READ Response
# SMB2_Session_Logoff_Request : SMB2 LOGOFF Request
# SMB2_Session_Logoff_Response : SMB2 LOGOFF Request
# SMB2_Session_Setup_Request : SMB2 Session Setup Request
# SMB2_Session_Setup_Response : SMB2 Session Setup Response
# SMB2_Transport_Capabilities : SMB2 Transport Capabilities
# SMB2_Tree_Connect_Request : SMB2 TREE_CONNECT Request
# SMB2_Tree_Connect_Response : SMB2 TREE_CONNECT Response
# SMB2_Tree_Disconnect_Request : SMB2 TREE_DISCONNECT Request
# SMB2_Tree_Disconnect_Response : SMB2 TREE_DISCONNECT Response
# SMB2_Write_Request : SMB2 WRITE Request
# SMB2_Write_Response : SMB2 WRITE Response
# SMBMailSlot : None
# SMBNegociate_Protocol_Request_Header_Generic : SMBNegociate Protocol Request Header Generic
# SMBNegotiate_Request : SMB Negotiate Request
# SMBNegotiate_Response_Extended_Security : SMB Negotiate Extended Security Response (SMB)
# SMBNegotiate_Response_NoSecurity : SMB Negotiate No-Security Response (CIFS)
# SMBNegotiate_Response_Security : SMB Negotiate Non-Extended Security Response (SMB)
# SMBNetlogon_Protocol_Response_Header : SMBNetlogon Protocol Response Header
# SMBNetlogon_Protocol_Response_Tail_LM20 : SMB Netlogon Protocol Response Tail LM20
# SMBNetlogon_Protocol_Response_Tail_SAM : SMB Netlogon Protocol Response Tail SAM
# SMBSession_Null : None
# SMBSession_Setup_AndX_Request : Session Setup AndX Request (CIFS)
# SMBSession_Setup_AndX_Request_Extended_Security : Session Setup AndX Extended Security Request (SMB)
# SMBSession_Setup_AndX_Response : Session Setup AndX Response (CIFS)
# SMBSession_Setup_AndX_Response_Extended_Security : Session Setup AndX Extended Security Response (SMB)
# SMBTree_Connect_AndX : Session Tree Connect AndX
# SMB_Dialect : SMB Dialect
# SMB_Header : SMB 1 Protocol Request Header
# SM_Confirm : Pairing Confirm
# SM_DHKey_Check : DHKey Check
# SM_Encryption_Information : Encryption Information
# SM_Failed  : Pairing Failed
# SM_Hdr     : SM header
# SM_Identity_Address_Information : Identity Address Information
# SM_Identity_Information : Identity Information
# SM_Master_Identification : Master Identification
# SM_Pairing_Request : Pairing Request
# SM_Pairing_Response : Pairing Response
# SM_Public_Key : Public Key
# SM_Random  : Pairing Random
# SM_Signing_Information : Signing Information
# SNAP       : SNAP
# SNMP       : None
# SNMPbulk   : None
# SNMPget    : None
# SNMPinform : None
# SNMPnext   : None
# SNMPresponse : None
# SNMPset    : None
# SNMPtrapv1 : None
# SNMPtrapv2 : None
# SNMPvarbind : None
# SPNEGO_MechListMIC : None
# SPNEGO_MechType : None
# SPNEGO_MechTypes : None
# SPNEGO_Token : None
# SPNEGO_negToken : None
# SPNEGO_negTokenInit : None
# SPNEGO_negTokenResp : None
# STP        : Spanning Tree Protocol
# Single_Host_Data : None
# SixLoWPAN  : SixLoWPAN Dispatcher
# SixLoWPAN_ESC : SixLoWPAN Dispatcher ESC
# Skinny     : Skinny
# TCP        : TCP
# TCPAOValue : None
# TCPerror   : TCP in ICMP
# TFTP       : TFTP opcode
# TFTP_ACK   : TFTP Ack
# TFTP_DATA  : TFTP Data
# TFTP_ERROR : TFTP Error
# TFTP_OACK  : TFTP Option Ack
# TFTP_Option : None
# TFTP_Options : None
# TFTP_RRQ   : TFTP Read Request
# TFTP_WRQ   : TFTP Write Request
# TransitedEncoding : None
# TransportInfoPacket : Transport Info
# UDP        : UDP
# UDPerror   : UDP in ICMP
# UPN_DNS_INFO : None
# USER_CLASS_DATA : user class data
# USER_SESSION_KEY : None
# VENDOR_CLASS_DATA : vendor class data
# VENDOR_SPECIFIC_OPTION : vendor specific option data
# VRRP       : None
# VRRPv3     : None
# VXLAN      : VXLAN
# VendorIdPacket : RTPS Vendor ID
# X509_AccessDescription : None
# X509_AlgorithmIdentifier : None
# X509_Attribute : None
# X509_AttributeTypeAndValue : None
# X509_AttributeValue : None
# X509_CRL   : None
# X509_Cert  : None
# X509_DNSName : None
# X509_DirectoryName : None
# X509_EDIPartyName : None
# X509_ExtAuthInfoAccess : None
# X509_ExtAuthorityKeyIdentifier : None
# X509_ExtBasicConstraints : None
# X509_ExtCRLDistributionPoints : None
# X509_ExtCRLNumber : None
# X509_ExtCertificateIssuer : None
# X509_ExtCertificatePolicies : None
# X509_ExtComment : None
# X509_ExtDefault : None
# X509_ExtDeltaCRLIndicator : None
# X509_ExtDistributionPoint : None
# X509_ExtDistributionPointName : None
# X509_ExtExtendedKeyUsage : None
# X509_ExtFreshestCRL : None
# X509_ExtFullName : None
# X509_ExtGeneralSubtree : None
# X509_ExtInhibitAnyPolicy : None
# X509_ExtInvalidityDate : None
# X509_ExtIssuerAltName : None
# X509_ExtIssuingDistributionPoint : None
# X509_ExtKeyUsage : None
# X509_ExtNameConstraints : None
# X509_ExtNameRelativeToCRLIssuer : None
# X509_ExtNetscapeCertType : None
# X509_ExtNoticeReference : None
# X509_ExtPolicyConstraints : None
# X509_ExtPolicyInformation : None
# X509_ExtPolicyMappings : None
# X509_ExtPolicyQualifierInfo : None
# X509_ExtPrivateKeyUsagePeriod : None
# X509_ExtQcStatement : None
# X509_ExtQcStatements : None
# X509_ExtReasonCode : None
# X509_ExtSubjInfoAccess : None
# X509_ExtSubjectAltName : None
# X509_ExtSubjectDirectoryAttributes : None
# X509_ExtSubjectKeyIdentifier : None
# X509_ExtUserNotice : None
# X509_Extension : None
# X509_Extensions : None
# X509_GeneralName : None
# X509_IPAddress : None
# X509_OtherName : None
# X509_PolicyMapping : None
# X509_RDN   : None
# X509_RFC822Name : None
# X509_RegisteredID : None
# X509_RevokedCertificate : None
# X509_SubjectPublicKeyInfo : None
# X509_TBSCertList : None
# X509_TBSCertificate : None
# X509_URI   : None
# X509_Validity : None
# X509_X400Address : None
# ZCLAttributeReport : ZCL Attribute Report
# ZCLConfigureReportingRecord : ZCL Configure Reporting Record
# ZCLConfigureReportingResponseRecord : ZCL Configure Reporting Response Record
# ZCLGeneralConfigureReporting : General Domain: Command Frame Payload: configure_reporting
# ZCLGeneralConfigureReportingResponse : General Domain: Command Frame Payload: configure_reporting_response
# ZCLGeneralDefaultResponse : General Domain: Command Frame Payload: default_response
# ZCLGeneralReadAttributes : General Domain: Command Frame Payload: read_attributes
# ZCLGeneralReadAttributesResponse : General Domain: Command Frame Payload: read_attributes_response
# ZCLGeneralReportAttributes : General Domain: Command Frame Payload: report_attributes
# ZCLGeneralWriteAttributes : General Domain: Command Frame Payload: write_attributes
# ZCLGeneralWriteAttributesResponse : General Domain: Command Frame Payload: write_attributes_response
# ZCLIASZoneZoneEnrollRequest : IAS Zone Cluster: Zone Enroll Request Command (Server: Generated)
# ZCLIASZoneZoneEnrollResponse : IAS Zone Cluster: Zone Enroll Response Command (Server: Received)
# ZCLIASZoneZoneStatusChangeNotification : IAS Zone Cluster: Zone Status Change Notification Command (Server: Generated)
# ZCLMeteringGetProfile : Metering Cluster: Get Profile Command (Server: Received)
# ZCLPriceGetCurrentPrice : Price Cluster: Get Current Price Command (Server: Received)
# ZCLPriceGetScheduledPrices : Price Cluster: Get Scheduled Prices Command (Server: Received)
# ZCLPricePublishPrice : Price Cluster: Publish Price Command (Server: Generated)
# ZCLReadAttributeStatusRecord : ZCL Read Attribute Status Record
# ZCLWriteAttributeRecord : ZCL Write Attribute Record
# ZCLWriteAttributeStatusRecord : ZCL Write Attribute Status Record
# ZDPActiveEPReq : ZDP Transaction Data: Active_EP_req
# ZDPDeviceAnnce : ZDP Transaction Data: Device_annce
# ZEP1       : Zigbee Encapsulation Protocol (V1)
# ZEP2       : Zigbee Encapsulation Protocol (V2)
# ZigBeeBeacon : ZigBee Beacon Payload
# ZigbeeAppCommandPayload : Zigbee Application Layer Command Payload
# ZigbeeAppDataPayload : Zigbee Application Layer Data Payload (General APS Frame Format)
# ZigbeeAppDataPayloadStub : Zigbee Application Layer Data Payload for Inter-PAN Transmission
# ZigbeeClusterLibrary : Zigbee Cluster Library (ZCL) Frame
# ZigbeeDeviceProfile : Zigbee Device Profile (ZDP) Frame
# ZigbeeNWK  : Zigbee Network Layer
# ZigbeeNWKCommandPayload : Zigbee Network Layer Command Payload
# ZigbeeNWKStub : Zigbee Network Layer for Inter-PAN Transmission
# ZigbeeSecurityHeader : Zigbee Security Header
# u_sub0     : None
# u_sub1     : None
# u_sub2     : None
# u_sub3     : None

# %%
ls(eth)
# Out:
#  Volume in drive H is HardDrive1TB
#  Volume Serial Number is 2002-2037
#
#  Directory of H:\Facultad\Redes
# File Not Found
